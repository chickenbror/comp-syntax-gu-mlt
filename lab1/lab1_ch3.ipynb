# %% [markdown]
# ## Chapter 1: explore the parallel UD treebank (PUD)
# 1. Go to https://universaldependencies.org/ (Links to an external site.) and download Version 2.7 treebanks
# 2. Look up the Parallel UD treebanks for those 19 languages that have it. They are named e.g. UD_English-PUD/
# 3. Select a language to compare with English.
# 4. Make statistics about the frequencies of POS tags and dependency labels in your language compared with English: find the top-20 tags/labels and their number of occurrences. What does this tell you about the language? (This can be done with shell or Python programming or with the gf-ud tool.)
# 5. Convert the following four trees from CoNLL format to graphical trees by hand, on paper.
#  - a short English tree (5-10 words, of your choice) and its translation.
#  - a long English tree (>25 words) and its translation.
# 6. Draw word alignments for some non-trivial example in the PUD treebank, on paper. Use the same trees as in the previous question. What can you say about the syntactic differences between the languages?

# %%
import pandas as pd
from string import punctuation

def process_text(file):
    '''Reads a TXT file and formats'''
    with open(file, 'r', encoding="utf8") as f:
        lines = [l.split() for l in f] #each line is a list of tokens
        for l in lines:
            if l[-1][0] not in punctuation:
                l.append('.')
        
        sents = []
        for l in lines:
            rows = []  # a row reps a token; a list of rows reps a sentence
            for i in range(len(l)):
                t = l[i]
                if ':<' in t:
                    word,pos = t.split(':<')[0],t.split(':<')[1][:-1]
                    row = [i+1, word, '_', pos, '_', '_', 'head', 'label', '_', '_' ] # ['position', 'word', '_', 'postag', '_', '_', 'head', 'label', '_', '_']
                    rows.append(row)
                else:
                    row = [i+1, t, '_', 'pos', '_', '_', 'head', 'label', '_', '_' ]
                    rows.append(row)
            
            og_text = '# text =' + ''.join([' '+r[1] if r[1][0] not in punctuation else r[1] for r in rows])
            rows.insert(0, og_text) # unshift
            for r in rows[1:]:
                r[0]=str(r[0])
            
            sents.append(rows)

    return sents

process_text('comp-syntax-corpus-english.txt')
# Out:
# [['# text = Who are they?',
#   ['1', 'Who', '_', 'PRON', '_', '_', 'head', 'label', '_', '_'],
#   ['2', 'are', '_', 'AUX', '_', '_', 'head', 'label', '_', '_'],
#   ['3', 'they', '_', 'PRON', '_', '_', 'head', 'label', '_', '_'],
#   ['4', '?', '_', 'PUNCT', '_', '_', 'head', 'label', '_', '_']],
#  ['# text = A small town with two minarets glides by.',
#   ['1', 'A', '_', 'DET', '_', '_', 'head', 'label', '_', '_'],
#   ['2', 'small', '_', 'ADJ', '_', '_', 'head', 'label', '_', '_'],
#   ['3', 'town', '_', 'NOUN', '_', '_', 'head', 'label', '_', '_'],
#   ['4', 'with', '_', 'ADP', '_', '_', 'head', 'label', '_', '_'],
#   ['5', 'two', '_', 'NUM', '_', '_', 'head', 'label', '_', '_'],
#   ['6', 'minarets', '_', 'NOUN', '_', '_', 'head', 'label', '_', '_'],
#   ['7', 'glides', '_', 'VERB', '_', '_', 'head', 'label', '_', '_'],
#   ['8', 'by', '_', 'ADV', '_', '_', 'head', 'label', '_', '_'],
#   ['9', '.', '_', 'PUNCT', '_', '_', 'head', 'label', '_', '_']],
#  ['# text = I was just a boy with muddy shoes.',
#   ['1', 'I', '_', 'PRON', '_', '_', 'head', 'label', '_', '_'],
#   ['2', 'was', '_', 'AUX', '_', '_', 'head', 'label', '_', '_'],
#   ['3', 'just', '_', 'ADV', '_', '_', 'head', 'label', '_', '_'],
#   ['4', 'a', '_', 'DET', '_', '_', 'head', 'label', '_', '_'],
#   ['5', 'boy', '_', 'NOUN', '_', '_', 'head', 'label', '_', '_'],
#   ['6', 'with', '_', 'ADP', '_', '_', 'head', 'label', '_', '_'],
#   ['7', 'muddy', '_', 'ADJ', '_', '_', 'head', 'label', '_', '_'],
#   ['8', 'shoes', '_', 'NOUN', '_', '_', 'head', 'label', '_', '_'],
#   ['9', '.', '_', 'PUNCT', '_', '_', 'head', 'label', '_', '_']],
#  ["# text = Shenzhen's traffic police have opted for unconventional penalties before.",
#   ['1', 'Shenzhen', '_', 'PROPN', '_', '_', 'head', 'label', '_', '_'],
#   ['2', "'s", '_', 'PART', '_', '_', 'head', 'label', '_', '_'],
#   ['3', 'traffic', '_', 'NOUN', '_', '_', 'head', 'label', '_', '_'],
#   ['4', 'police', '_', 'NOUN', '_', '_', 'head', 'label', '_', '_'],
#   ['5', 'have', '_', 'AUX', '_', '_', 'head', 'label', '_', '_'],
#   ['6', 'opted', '_', 'VERB', '_', '_', 'head', 'label', '_', '_'],
#   ['7', 'for', '_', 'ADP', '_', '_', 'head', 'label', '_', '_'],
#   ['8', 'unconventional', '_', 'ADJ', '_', '_', 'head', 'label', '_', '_'],
#   ['9', 'penalties', '_', 'NOUN', '_', '_', 'head', 'label', '_', '_'],
#   ['10', 'before', '_', 'ADV', '_', '_', 'head', 'label', '_', '_'],
#   ['11', '.', '_', 'PUNCT>', '_', '_', 'head', 'label', '_', '_']],
#  ['# text = The study of volcanoes is called volcanology, sometimes spelled vulcanology.',
#   ['1', 'The', '_', 'DET', '_', '_', 'head', 'label', '_', '_'],
#   ['2', 'study', '_', 'NOUN', '_', '_', 'head', 'label', '_', '_'],
#   ['3', 'of', '_', 'ADP', '_', '_', 'head', 'label', '_', '_'],
#   ['4', 'volcanoes', '_', 'NOUN', '_', '_', 'head', 'label', '_', '_'],
#   ['5', 'is', '_', 'AUX', '_', '_', 'head', 'label', '_', '_'],
#   ['6', 'called', '_', 'VERB', '_', '_', 'head', 'label', '_', '_'],
#   ['7', 'volcanology', '_', 'NOUN', '_', '_', 'head', 'label', '_', '_'],
#   ['8', ',', '_', 'PUNCT', '_', '_', 'head', 'label', '_', '_'],
#   ['9', 'sometimes', '_', 'ADV', '_', '_', 'head', 'label', '_', '_'],
#   ['10', 'spelled', '_', 'VERB', '_', '_', 'head', 'label', '_', '_'],
#   ['11', 'vulcanology', '_', 'NOUN', '_', '_', 'head', 'label', '_', '_'],
#   ['12', '.', '_', 'PUNCT', '_', '_', 'head', 'label', '_', '_']],
#  ['# text = It was conducted just off the Mexican coast from April to June.',
#   ['1', 'It', '_', 'PRON', '_', '_', 'head', 'label', '_', '_'],
#   ['2', 'was', '_', 'AUX', '_', '_', 'head', 'label', '_', '_'],
#   ['3', 'conducted', '_', 'VERB', '_', '_', 'head', 'label', '_', '_'],
#   ['4', 'just', '_', 'ADV', '_', '_', 'head', 'label', '_', '_'],
#   ['5', 'off', '_', 'ADP', '_', '_', 'head', 'label', '_', '_'],
#   ['6', 'the', '_', 'DET', '_', '_', 'head', 'label', '_', '_'],
#   ['7', 'Mexican', '_', 'ADJ', '_', '_', 'head', 'label', '_', '_'],
#   ['8', 'coast', '_', 'NOUN', '_', '_', 'head', 'label', '_', '_'],
#   ['9', 'from', '_', 'ADP', '_', '_', 'head', 'label', '_', '_'],
#   ['10', 'April', '_', 'PROPN', '_', '_', 'head', 'label', '_', '_'],
#   ['11', 'to', '_', 'ADP', '_', '_', 'head', 'label', '_', '_'],
#   ['12', 'June', '_', 'PROPN', '_', '_', 'head', 'label', '_', '_'],
#   ['13', '.', '_', 'PUNCT', '_', '_', 'head', 'label', '_', '_']],
#  ['# text =" Her voice literally went around the world," Leive said.',
#   ['1', '"', '_', 'PUNCT', '_', '_', 'head', 'label', '_', '_'],
#   ['2', 'Her', '_', 'PRON', '_', '_', 'head', 'label', '_', '_'],
#   ['3', 'voice', '_', 'NOUN', '_', '_', 'head', 'label', '_', '_'],
#   ['4', 'literally', '_', 'ADV', '_', '_', 'head', 'label', '_', '_'],
#   ['5', 'went', '_', 'VERB', '_', '_', 'head', 'label', '_', '_'],
#   ['6', 'around', '_', 'ADP', '_', '_', 'head', 'label', '_', '_'],
#   ['7', 'the', '_', 'DET', '_', '_', 'head', 'label', '_', '_'],
#   ['8', 'world', '_', 'NOUN', '_', '_', 'head', 'label', '_', '_'],
#   ['9', ',', '_', 'PUNCT', '_', '_', 'head', 'label', '_', '_'],
#   ['10', '"', '_', 'PUNCT', '_', '_', 'head', 'label', '_', '_'],
#   ['11', 'Leive', '_', 'PROPN', '_', '_', 'head', 'label', '_', '_'],
#   ['12', 'said', '_', 'VERB', '_', '_', 'head', 'label', '_', '_'],
#   ['13', '.', '_', 'PUNCT', '_', '_', 'head', 'label', '_', '_']],
#  ['# text = A witness told police that the victim had attacked the suspect in April.',
#   ['1', 'A', '_', 'DET', '_', '_', 'head', 'label', '_', '_'],
#   ['2', 'witness', '_', 'NOUN', '_', '_', 'head', 'label', '_', '_'],
#   ['3', 'told', '_', 'VERB', '_', '_', 'head', 'label', '_', '_'],
#   ['4', 'police', '_', 'NOUN', '_', '_', 'head', 'label', '_', '_'],
#   ['5', 'that', '_', 'SCONJ', '_', '_', 'head', 'label', '_', '_'],
#   ['6', 'the', '_', 'DET', '_', '_', 'head', 'label', '_', '_'],
#   ['7', 'victim', '_', 'NOUN', '_', '_', 'head', 'label', '_', '_'],
#   ['8', 'had', '_', 'AUX', '_', '_', 'head', 'label', '_', '_'],
#   ['9', 'attacked', '_', 'VERB', '_', '_', 'head', 'label', '_', '_'],
#   ['10', 'the', '_', 'DET', '_', '_', 'head', 'label', '_', '_'],
#   ['11', 'suspect', '_', 'NOUN', '_', '_', 'head', 'label', '_', '_'],
#   ['12', 'in', '_', 'ADP', '_', '_', 'head', 'label', '_', '_'],
#   ['13', 'April', '_', 'PROPN', '_', '_', 'head', 'label', '_', '_'],
#   ['14', '.', '_', 'PUNCT', '_', '_', 'head', 'label', '_', '_']],
#  ["# text = It's most obvious when a celebrity's name is initially quite rare.",
#   ['1', 'It', '_', 'PRON', '_', '_', 'head', 'label', '_', '_'],
#   ['2', "'s", '_', 'AUX', '_', '_', 'head', 'label', '_', '_'],
#   ['3', 'most', '_', 'ADV', '_', '_', 'head', 'label', '_', '_'],
#   ['4', 'obvious', '_', 'ADJ', '_', '_', 'head', 'label', '_', '_'],
#   ['5', 'when', '_', 'SSUBJ', '_', '_', 'head', 'label', '_', '_'],
#   ['6', 'a', '_', 'DET', '_', '_', 'head', 'label', '_', '_'],
#   ['7', 'celebrity', '_', 'NOUN', '_', '_', 'head', 'label', '_', '_'],
#   ['8', "'s", '_', 'PART', '_', '_', 'head', 'label', '_', '_'],
#   ['9', 'name', '_', 'NOUN', '_', '_', 'head', 'label', '_', '_'],
#   ['10', 'is', '_', 'AUX', '_', '_', 'head', 'label', '_', '_'],
#   ['11', 'initially', '_', 'ADV', '_', '_', 'head', 'label', '_', '_'],
#   ['12', 'quite', '_', 'ADV', '_', '_', 'head', 'label', '_', '_'],
#   ['13', 'rare', '_', 'ADJ', '_', '_', 'head', 'label', '_', '_'],
#   ['14', '.', '_', 'PUNCT', '_', '_', 'head', 'label', '_', '_']],
#  ['# text = This has not stopped investors flocking to put their money in the funds.',
#   ['1', 'This', '_', 'PRON', '_', '_', 'head', 'label', '_', '_'],
#   ['2', 'has', '_', 'AUX', '_', '_', 'head', 'label', '_', '_'],
#   ['3', 'not', '_', 'PART', '_', '_', 'head', 'label', '_', '_'],
#   ['4', 'stopped', '_', 'VERB', '_', '_', 'head', 'label', '_', '_'],
#   ['5', 'investors', '_', 'NOUN', '_', '_', 'head', 'label', '_', '_'],
#   ['6', 'flocking', '_', 'VERB', '_', '_', 'head', 'label', '_', '_'],
#   ['7', 'to', '_', 'PART', '_', '_', 'head', 'label', '_', '_'],
#   ['8', 'put', '_', 'VERB', '_', '_', 'head', 'label', '_', '_'],
#   ['9', 'their', '_', 'PRON', '_', '_', 'head', 'label', '_', '_'],
#   ['10', 'money', '_', 'NOUN', '_', '_', 'head', 'label', '_', '_'],
#   ['11', 'in', '_', 'ADP', '_', '_', 'head', 'label', '_', '_'],
#   ['12', 'the', '_', 'DET', '_', '_', 'head', 'label', '_', '_'],
#   ['13', 'funds', '_', 'NOUN', '_', '_', 'head', 'label', '_', '_'],
#   ['14', '.', '_', 'PUNCT', '_', '_', 'head', 'label', '_', '_']],
#  ['# text = This discordance between economic data and political rhetoric is familiar, or should be.',
#   ['1', 'This', '_', 'DET', '_', '_', 'head', 'label', '_', '_'],
#   ['2', 'discordance', '_', 'NOUN', '_', '_', 'head', 'label', '_', '_'],
#   ['3', 'between', '_', 'ADP', '_', '_', 'head', 'label', '_', '_'],
#   ['4', 'economic', '_', 'ADJ', '_', '_', 'head', 'label', '_', '_'],
#   ['5', 'data', '_', 'NOUN', '_', '_', 'head', 'label', '_', '_'],
#   ['6', 'and', '_', 'CCONJ', '_', '_', 'head', 'label', '_', '_'],
#   ['7', 'political', '_', 'ADJ', '_', '_', 'head', 'label', '_', '_'],
#   ['8', 'rhetoric', '_', 'NOUN', '_', '_', 'head', 'label', '_', '_'],
#   ['9', 'is', '_', 'AUX', '_', '_', 'head', 'label', '_', '_'],
#   ['10', 'familiar', '_', 'ADJ', '_', '_', 'head', 'label', '_', '_'],
#   ['11', ',', '_', 'PUNCT', '_', '_', 'head', 'label', '_', '_'],
#   ['12', 'or', '_', 'CCONJ', '_', '_', 'head', 'label', '_', '_'],
#   ['13', 'should', '_', 'AUX', '_', '_', 'head', 'label', '_', '_'],
#   ['14', 'be', '_', 'AUX', '_', '_', 'head', 'label', '_', '_'],
#   ['15', '.', '_', 'PUNCT', '_', '_', 'head', 'label', '_', '_']],
#  ['# text = The feasibility study estimates that it would take passengers about four minutes to cross the Potomac River on the gondola.',
#   ['1', 'The', '_', 'DET', '_', '_', 'head', 'label', '_', '_'],
#   ['2', 'feasibility', '_', 'NOUN', '_', '_', 'head', 'label', '_', '_'],
#   ['3', 'study', '_', 'NOUN', '_', '_', 'head', 'label', '_', '_'],
#   ['4', 'estimates', '_', 'VERB', '_', '_', 'head', 'label', '_', '_'],
#   ['5', 'that', '_', 'SCONJ', '_', '_', 'head', 'label', '_', '_'],
#   ['6', 'it', '_', 'PRON', '_', '_', 'head', 'label', '_', '_'],
#   ['7', 'would', '_', 'AUX', '_', '_', 'head', 'label', '_', '_'],
#   ['8', 'take', '_', 'VERB', '_', '_', 'head', 'label', '_', '_'],
#   ['9', 'passengers', '_', 'NOUN', '_', '_', 'head', 'label', '_', '_'],
#   ['10', 'about', '_', 'ADV', '_', '_', 'head', 'label', '_', '_'],
#   ['11', 'four', '_', 'NUM', '_', '_', 'head', 'label', '_', '_'],
#   ['12', 'minutes', '_', 'NOUN', '_', '_', 'head', 'label', '_', '_'],
#   ['13', 'to', '_', 'PART', '_', '_', 'head', 'label', '_', '_'],
#   ['14', 'cross', '_', 'VERB', '_', '_', 'head', 'label', '_', '_'],
#   ['15', 'the', '_', 'DET', '_', '_', 'head', 'label', '_', '_'],
#   ['16', 'Potomac', '_', 'PROPN', '_', '_', 'head', 'label', '_', '_'],
#   ['17', 'River', '_', 'PROPN', '_', '_', 'head', 'label', '_', '_'],
#   ['18', 'on', '_', 'ADP', '_', '_', 'head', 'label', '_', '_'],
#   ['19', 'the', '_', 'DET', '_', '_', 'head', 'label', '_', '_'],
#   ['20', 'gondola', '_', 'NOUN', '_', '_', 'head', 'label', '_', '_'],
#   ['21', '.', '_', 'PUNCT', '_', '_', 'head', 'label', '_', '_']],
#  ['# text = he collected cards and traded them with the other boys.',
#   ['1', 'he', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['2', 'collected', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['3', 'cards', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['4', 'and', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['5', 'traded', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['6', 'them', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['7', 'with', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['8', 'the', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['9', 'other', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['10', 'boys', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['11', '.', '_', 'pos', '_', '_', 'head', 'label', '_', '_']],
#  ['# text = this crime carries a penalty of five years in prison.',
#   ['1', 'this', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['2', 'crime', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['3', 'carries', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['4', 'a', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['5', 'penalty', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['6', 'of', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['7', 'five', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['8', 'years', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['9', 'in', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['10', 'prison', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['11', '.', '_', 'pos', '_', '_', 'head', 'label', '_', '_']],
#  ['# text = the news was carried to every village in the province.',
#   ['1', 'the', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['2', 'news', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['3', 'was', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['4', 'carried', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['5', 'to', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['6', 'every', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['7', 'village', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['8', 'in', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['9', 'the', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['10', 'province', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['11', '.', '_', 'pos', '_', '_', 'head', 'label', '_', '_']],
#  ['# text = I carry these thoughts in the back of my head.',
#   ['1', 'I', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['2', 'carry', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['3', 'these', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['4', 'thoughts', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['5', 'in', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['6', 'the', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['7', 'back', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['8', 'of', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['9', 'my', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['10', 'head', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['11', '.', '_', 'pos', '_', '_', 'head', 'label', '_', '_']],
#  ['# text = Adam would have been carried over into the life eternal.',
#   ['1', 'Adam', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['2', 'would', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['3', 'have', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['4', 'been', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['5', 'carried', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['6', 'over', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['7', 'into', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['8', 'the', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['9', 'life', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['10', 'eternal', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['11', '.', '_', 'pos', '_', '_', 'head', 'label', '_', '_']],
#  ['# text = the casings had rotted away and had to be replaced.',
#   ['1', 'the', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['2', 'casings', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['3', 'had', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['4', 'rotted', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['5', 'away', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['6', 'and', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['7', 'had', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['8', 'to', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['9', 'be', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['10', 'replaced', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['11', '.', '_', 'pos', '_', '_', 'head', 'label', '_', '_']],
#  ['# text = she was incensed that this chit of a girl should dare to make a fool of her in front of the class.',
#   ['1', 'she', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['2', 'was', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['3', 'incensed', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['4', 'that', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['5', 'this', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['6', 'chit', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['7', 'of', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['8', 'a', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['9', 'girl', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['10', 'should', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['11', 'dare', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['12', 'to', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['13', 'make', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['14', 'a', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['15', 'fool', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['16', 'of', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['17', 'her', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['18', 'in', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['19', 'front', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['20', 'of', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['21', 'the', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['22', 'class', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['23', '.', '_', 'pos', '_', '_', 'head', 'label', '_', '_']],
#  ['# text = the landslide he had in the electoral college obscured the narrowness of a victory based on just 43% of the popular vote.',
#   ['1', 'the', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['2', 'landslide', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['3', 'he', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['4', 'had', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['5', 'in', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['6', 'the', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['7', 'electoral', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['8', 'college', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['9', 'obscured', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['10', 'the', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['11', 'narrowness', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['12', 'of', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['13', 'a', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['14', 'victory', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['15', 'based', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['16', 'on', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['17', 'just', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['18', '43%', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['19', 'of', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['20', 'the', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['21', 'popular', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['22', 'vote', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['23', '.', '_', 'pos', '_', '_', 'head', 'label', '_', '_']],
#  ['# text = United States troops now carry atropine and autoinjectors in their first-aid kits to use in case of organophosphate nerve agent poisoning.',
#   ['1', 'United', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['2', 'States', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['3', 'troops', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['4', 'now', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['5', 'carry', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['6', 'atropine', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['7', 'and', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['8', 'autoinjectors', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['9', 'in', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['10', 'their', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['11', 'first-aid', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['12', 'kits', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['13', 'to', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['14', 'use', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['15', 'in', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['16', 'case', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['17', 'of', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['18', 'organophosphate', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['19', 'nerve', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['20', 'agent', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['21', 'poisoning', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['22', '.', '_', 'pos', '_', '_', 'head', 'label', '_', '_']],
#  ['# text = he may accomplish by craft in the long run what he cannot do by force and violence in the short one.',
#   ['1', 'he', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['2', 'may', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['3', 'accomplish', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['4', 'by', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['5', 'craft', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['6', 'in', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['7', 'the', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['8', 'long', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['9', 'run', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['10', 'what', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['11', 'he', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['12', 'cannot', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['13', 'do', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['14', 'by', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['15', 'force', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['16', 'and', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['17', 'violence', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['18', 'in', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['19', 'the', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['20', 'short', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['21', 'one', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['22', '.', '_', 'pos', '_', '_', 'head', 'label', '_', '_']],
#  ['# text = it has been said that only a hierarchical society with a leisure class at the top can produce works of art.',
#   ['1', 'it', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['2', 'has', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['3', 'been', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['4', 'said', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['5', 'that', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['6', 'only', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['7', 'a', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['8', 'hierarchical', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['9', 'society', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['10', 'with', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['11', 'a', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['12', 'leisure', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['13', 'class', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['14', 'at', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['15', 'the', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['16', 'top', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['17', 'can', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['18', 'produce', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['19', 'works', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['20', 'of', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['21', 'art', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['22', '.', '_', 'pos', '_', '_', 'head', 'label', '_', '_']],
#  ['# text = his ingenuous explanation that he would not have burned the church if he had not thought the bishop was in it.',
#   ['1', 'his', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['2', 'ingenuous', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['3', 'explanation', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['4', 'that', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['5', 'he', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['6', 'would', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['7', 'not', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['8', 'have', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['9', 'burned', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['10', 'the', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['11', 'church', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['12', 'if', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['13', 'he', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['14', 'had', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['15', 'not', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['16', 'thought', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['17', 'the', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['18', 'bishop', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['19', 'was', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['20', 'in', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['21', 'it', '_', 'pos', '_', '_', 'head', 'label', '_', '_'],
#   ['22', '.', '_', 'pos', '_', '_', 'head', 'label', '_', '_']]]

# %%
lang = 'english'
sents = process_text(f'comp-syntax-corpus-{lang}.txt')
new_sents = []
for sen in sents:
    new_sent = [sen[0]]
    for r in sen[1:]:
        new_sent.append('\t'.join(r))
    new_sents.append(new_sent)
    
with open(f'{lang}-tab-separated.txt', 'w') as f:
    for sent in new_sents:
        for r in sent:
            f.write(r+'\n')
        f.write('\n\n')

# %%
eng_sents = [s[0].replace('text', 'text_en',1) for s in sents]
eng_sents
# Out:
# ['# text_en = Who are they?',
#  '# text_en = A small town with two minarets glides by.',
#  '# text_en = I was just a boy with muddy shoes.',
#  "# text_en = Shenzhen's traffic police have opted for unconventional penalties before.",
#  '# text_en = The study of volcanoes is called volcanology, sometimes spelled vulcanology.',
#  '# text_en = It was conducted just off the Mexican coast from April to June.',
#  '# text_en =" Her voice literally went around the world," Leive said.',
#  '# text_en = A witness told police that the victim had attacked the suspect in April.',
#  "# text_en = It's most obvious when a celebrity's name is initially quite rare.",
#  '# text_en = This has not stopped investors flocking to put their money in the funds.',
#  '# text_en = This discordance between economic data and political rhetoric is familiar, or should be.',
#  '# text_en = The feasibility study estimates that it would take passengers about four minutes to cross the Potomac River on the gondola.',
#  '# text_en = he collected cards and traded them with the other boys.',
#  '# text_en = this crime carries a penalty of five years in prison.',
#  '# text_en = the news was carried to every village in the province.',
#  '# text_en = I carry these thoughts in the back of my head.',
#  '# text_en = Adam would have been carried over into the life eternal.',
#  '# text_en = the casings had rotted away and had to be replaced.',
#  '# text_en = she was incensed that this chit of a girl should dare to make a fool of her in front of the class.',
#  '# text_en = the landslide he had in the electoral college obscured the narrowness of a victory based on just 43% of the popular vote.',
#  '# text_en = United States troops now carry atropine and autoinjectors in their first-aid kits to use in case of organophosphate nerve agent poisoning.',
#  '# text_en = he may accomplish by craft in the long run what he cannot do by force and violence in the short one.',
#  '# text_en = it has been said that only a hierarchical society with a leisure class at the top can produce works of art.',
#  '# text_en = his ingenuous explanation that he would not have burned the church if he had not thought the bishop was in it.']

# %%
enumerate(translations)

# %%
with open(f'chinese-tab-separated.txt', 'w', encoding='utf8') as f:
    for sent in text_tokens:
        f.write(sent[0]+'\n')
        f.write(sent[1]+'\n')
        for r in sent[2]:
            f.write(r+'\n')
        f.write('\n\n')
