# %% [markdown]
# ## Chapter 1: explore the parallel UD treebank (PUD)
# 1. Go to https://universaldependencies.org/ (Links to an external site.) and download Version 2.7 treebanks
# 2. Look up the Parallel UD treebanks for those 19 languages that have it. They are named e.g. UD_English-PUD/
# 3. Select a language to compare with English.
# 4. Make statistics about the frequencies of POS tags and dependency labels in your language compared with English: find the top-20 tags/labels and their number of occurrences. What does this tell you about the language? (This can be done with shell or Python programming or with the gf-ud tool.)
# 5. Convert the following four trees from CoNLL format to graphical trees by hand, on paper.
#  - a short English tree (5-10 words, of your choice) and its translation.
#  - a long English tree (>25 words) and its translation.
# 6. Draw word alignments for some non-trivial example in the PUD treebank, on paper. Use the same trees as in the previous question. What can you say about the syntactic differences between the languages?

# %% [markdown]
# https://universaldependencies.org/format.html
# * ID: Word index, integer starting at 1 for each new sentence; may be a range for multiword tokens; may be a decimal number for empty nodes (decimal numbers can be lower than 1 but must be greater than 0).
# * FORM: Word form or punctuation symbol.
# * LEMMA: Lemma or stem of word form.
# * UPOS: Universal part-of-speech tag.
# * XPOS: Language-specific part-of-speech tag; underscore if not available.
# * FEATS: List of morphological features from the universal feature inventory or from a defined language-specific extension; underscore if not available.
# * HEAD: Head of the current word, which is either a value of ID or zero (0).
# * DEPREL: Universal dependency relation to the HEAD (root iff HEAD = 0) or a defined language-specific subtype of one.
# * DEPS: Enhanced dependency graph in the form of a list of head-deprel pairs.
# * MISC:

# %%
import pandas as pd
def process_conllu(file):
    '''Reads a PUD file and returns a dataframe of tokens'''
    with open(file, 'r', encoding="utf8") as f:
        lines = [l.split('\t') for l in f]
        lines = [l for l in lines if len(l)==10 ]
        for l in lines:
            l[9] = l[9].rstrip('\n')

    tabs = ['id','form','lemma','upos','xpos','feats','head','deprel','deps','misc']
    return pd.DataFrame(lines, columns= tabs)

# %%
Chinese_PUD = 'UD_Chinese-PUD/zh_pud-ud-test.conllu'
English_PUD = 'UD_English-PUD/en_pud-ud-test.conllu'
df_chinese = process_conllu(Chinese_PUD)
df_english = process_conllu(English_PUD)
df_chinese
# Out:
#        id form lemma   upos xpos         feats head      deprel deps                           misc
# 0       1    "     _  PUNCT   ``             _   18       punct    _       SpaceAfter=No|Translit="
# 1       2   雖然     _  SCONJ   IN             _    8        mark    _  SpaceAfter=No|Translit=suīrán
# 2       3   美國     _  PROPN  NNP             _    7        nmod    _  SpaceAfter=No|Translit=měiguó
# 3       4    的     _   PART  DEC      Case=Gen    3        case    _      SpaceAfter=No|Translit=de
# 4       5   許多     _    NUM   CD  NumType=Card    7      nummod    _   SpaceAfter=No|Translit=xǔduō
# ...    ..  ...   ...    ...  ...           ...  ...         ...  ...                            ...
# 21410  31   和平     _    ADJ   JJ             _   34        amod    _  SpaceAfter=No|Translit=hépíng
# 21411  32    的     _   PART  DEC             _   31  mark:relcl    _      SpaceAfter=No|Translit=de
# 21412  33   友誼     _   NOUN   NN             _   34    compound    _   SpaceAfter=No|Translit=youyì
# 21413  34   關係     _   NOUN   NN             _   30         obj    _   SpaceAfter=No|Translit=guān係
# 21414  35    。     _  PUNCT    .             _   24       punct    _                     Translit=。
#
# [21415 rows x 10 columns]

# %%
df_english[ df_english.feats!='_' ] # SELECT rows FROM df WHERE df.feat != '_'
# Out:
#        id        form       lemma  upos  ... head     deprel                   deps           misc
# 2       3        much        much   ADJ  ...    9      nsubj                9:nsubj              _
# 4       5         the         the   DET  ...    7        det                  7:det              _
# 5       6     digital     digital   ADJ  ...    7       amod                 7:amod              _
# 6       7  transition  transition  NOUN  ...    3       nmod              3:nmod:of              _
# 7       8          is          be   AUX  ...    9        cop                  9:cop              _
# ...    ..         ...         ...   ...  ...  ...        ...                    ...            ...
# 21176  19    declared     declare  VERB  ...   12  acl:relcl           12:acl:relcl              _
# 21177  20     himself     himself  PRON  ...   19        obj  19:obj|22:nsubj:xsubj              _
# 21178  21           a           a   DET  ...   22        det                 22:det              _
# 21179  22      friend      friend  NOUN  ...   19      xcomp               19:xcomp              _
# 21181  24       peace       peace  NOUN  ...   22       nmod             22:nmod:of  SpaceAfter=No
#
# [14183 rows x 10 columns]

# %%
# SELECT * FROM df WHERE df.feat!='_' 
df_chinese[ df_chinese.feats!='_']
# Out:
#        id form lemma  upos xpos         feats head  deprel deps                          misc
# 3       4    的     _  PART  DEC      Case=Gen    3    case    _     SpaceAfter=No|Translit=de
# 4       5   許多     _   NUM   CD  NumType=Card    7  nummod    _  SpaceAfter=No|Translit=xǔduō
# 13     14    的     _  PART  DEC      Case=Gen   13    case    _     SpaceAfter=No|Translit=de
# 22     23    的     _  PART  DEC      Case=Gen   22    case    _     SpaceAfter=No|Translit=de
# 30     31    一     _   NUM   CD  NumType=Card   30  nummod    _     SpaceAfter=No|Translit=yī
# ...    ..  ...   ...   ...  ...           ...  ...     ...  ...                           ...
# 21384   5    1     _   NUM   CD  NumType=Card    6  nummod    _      SpaceAfter=No|Translit=1
# 21386   7    1     _   NUM   CD  NumType=Card    8  nummod    _      SpaceAfter=No|Translit=1
# 21393  14    了     _  PART   AS   Aspect=Perf   13     aux    _     SpaceAfter=No|Translit=le
# 21394  15    一     _   NUM   CD  NumType=Card   16  nummod    _     SpaceAfter=No|Translit=yī
# 21408  29    他     _  PRON  PRP      Person=3   30     obl    _     SpaceAfter=No|Translit=tā
#
# [2969 rows x 10 columns]

# %%
lex = df_chinese.upos.to_dict()
idxs=[nr for (nr, pos) in lex.items() if pos=='NOUN' and lex[nr+1]=='VERB']

# %%
for i in idxs:
    print(df_chinese[i:i+2])
# Out:
#   id form lemma  upos xpos feats head deprel deps                              misc
# 6  7   轉型     _  NOUN   NN     _    8  nsubj    _  SpaceAfter=No|Translit=zhuǎnxíng
# 7  8   都是     _  VERB   VC     _   18  advcl    _     SpaceAfter=No|Translit=dōushì
#    id form lemma  upos xpos feats head     deprel deps                            misc
# 66  8    次     _  NOUN  NNB     _   16        clf    _       SpaceAfter=No|Translit=cì
# 67  9   進行     _  VERB   VV     _   16  acl:relcl    _  SpaceAfter=No|Translit=jìnxíng
#     id form lemma  upos xpos feats head    deprel deps                                           misc
# 78  20  共和黨     _  NOUN   NN     _   21  compound    _  Proper=True|SpaceAfter=No|Translit=gònghédǎng
# 79  21  候選人     _  VERB   VV     _   18       obj    _              SpaceAfter=No|Translit=houxuǎnrén
#      id form lemma  upos xpos feats head    deprel deps                                      misc
# 130  27   大學     _  NOUN   NN     _   28  compound    _  Proper=True|SpaceAfter=No|Translit=dàxué
# 131  28  運動場     _  VERB   VV     _   25       obj    _       SpaceAfter=No|Translit=yùndòngchǎng
#      id form lemma  upos xpos feats head deprel deps                             misc
# 134  31   群眾     _  NOUN   NN     _   32    obl    _  SpaceAfter=No|Translit=qúnzhòng
# 135  32   說道     _  VERB   VV     _    0   root    _   SpaceAfter=No|Translit=shuōdào
#     id form lemma  upos xpos      feats head deprel deps                            misc
# 141  5   帳戶     _  NOUN   NN          _    6  nsubj    _  SpaceAfter=No|Translit=zhànghù
# 142  6    使     _  VERB   VV  Voice=Cau    0   root    _      SpaceAfter=No|Translit=shǐ
#     id form lemma  upos xpos feats head deprel deps                            misc
# 143  7   政府     _  NOUN   NN     _    8  nsubj    _  SpaceAfter=No|Translit=zhèngfǔ
# 144  8   支出     _  VERB   VV     _   10  csubj    _   SpaceAfter=No|Translit=zhīchū
#     id  form lemma  upos xpos feats head deprel deps                                misc
# 157  8     人     _  NOUN   NN     _    9  nsubj    _          SpaceAfter=No|Translit=rén
# 158  9  難以置信     _  VERB   VV     _    7  ccomp    _  SpaceAfter=No|Translit=nányǐzhìxìn
#     id form lemma  upos xpos feats head deprel deps                            misc
# 175  8   團隊     _  NOUN   NN     _   14  nsubj    _  SpaceAfter=No|Translit=tuánduì
# 176  9    在     _  VERB   VV     _   14  advcl    _      SpaceAfter=No|Translit=zài
#      id form lemma  upos xpos feats head deprel deps                                       misc
# 226  19  俱樂部     _  NOUN   NN     _   20    obl    _  Proper=True|SpaceAfter=No|Translit=jùlèbù
# 227  20   舉行     _  VERB   VV     _    5  xcomp    _              SpaceAfter=No|Translit=jǔxíng
#     id form lemma  upos xpos feats head       deprel deps                           misc
# 241  6   方法     _  NOUN   NN     _   15  obl:patient    _  SpaceAfter=No|Translit=fāngfǎ
# 242  7    作     _  VERB   VV     _   15        advcl    _     SpaceAfter=No|Translit=zuò
#      id form lemma  upos xpos feats head     deprel deps                         misc
# 245  10    個     _  NOUN  NNB     _   13        clf    _    SpaceAfter=No|Translit=gè
# 246  11   獨立     _  VERB   VV     _   13  acl:relcl    _  SpaceAfter=No|Translit=dúlì
#     id form lemma  upos xpos feats head deprel deps                            misc
# 267  3   成績     _  NOUN   NN     _   14  nsubj    _  SpaceAfter=No|Translit=chéngjī
# 268  4    屬     _  VERB   VV     _   14  advcl    _      SpaceAfter=No|Translit=shǔ
#     id form lemma  upos xpos feats head     deprel deps                          misc
# 292  6    年     _  NOUN  NNB     _    7        obl    _   SpaceAfter=No|Translit=nián
# 293  7   開業     _  VERB   VV     _   11  acl:relcl    _  SpaceAfter=No|Translit=kāiyè
#      id form lemma  upos xpos feats head    deprel deps                                          misc
# 297  11  地鐵站     _  NOUN   NN     _   15  compound    _  Proper=True|SpaceAfter=No|Translit=detiězhàn
# 298  12   修建     _  VERB   VV     _   14     advcl    _                SpaceAfter=No|Translit=xiūjiàn
#      id form lemma  upos xpos feats head deprel deps                           misc
# 321  15   局面     _  NOUN   NN     _   16    obl    _  SpaceAfter=No|Translit=júmiàn
# 322  16    有     _  VERB   VV     _    9  ccomp    _     SpaceAfter=No|Translit=yǒu
#      id form lemma  upos xpos feats head    deprel deps                                           misc
# 328  22   商業     _  NOUN   NN     _   24  compound    _     Proper=True|SpaceAfter=No|Translit=shāngyè
# 329  23  改善會     _  VERB   VV     _   24  compound    _  Proper=True|SpaceAfter=No|Translit=gǎishànhuì
#     id form lemma  upos xpos feats head deprel deps                           misc
# 338  3   研究     _  NOUN   NN     _    4    obl    _  SpaceAfter=No|Translit=yánjiū
# 339  4   估計     _  VERB   VV     _    0   root    _    SpaceAfter=No|Translit=gūjì
#     id form lemma  upos xpos feats head deprel deps                             misc
# 341  6   乘客     _  NOUN   NN     _    9  nsubj    _   SpaceAfter=No|Translit=chéngkè
# 342  7   乘坐     _  VERB   VV     _    9  advcl    _  SpaceAfter=No|Translit=chéngzuò
#     id form lemma  upos xpos feats head deprel deps                             misc
# 343  8   纜車     _  NOUN   NN     _    7    obj    _      SpaceAfter=No|Translit=纜chē
# 344  9   穿越     _  VERB   VV     _   11  csubj    _  SpaceAfter=No|Translit=chuānyuè
#     id form lemma  upos xpos feats head deprel deps                            misc
# 352  2    位     _  NOUN  NNB     _    3    clf    _      SpaceAfter=No|Translit=wèi
# 353  3  目擊者     _  VERB   VV     _    4  nsubj    _  SpaceAfter=No|Translit=mùjīzhě
#      id form lemma  upos xpos feats head deprel deps                         misc
# 362  12    月     _  NOUN  NNB     _   13    obl    _   SpaceAfter=No|Translit=yuè
# 363  13   襲擊     _  VERB   VV     _    0   root    _  SpaceAfter=No|Translit=xíjī
#     id form lemma  upos xpos feats head deprel deps                             misc
# 372  6   生活     _  NOUN   NN     _    7    obl    _  SpaceAfter=No|Translit=shēnghuó
# 373  7    有     _  VERB   VV     _    0   root    _       SpaceAfter=No|Translit=yǒu
#      id form lemma  upos xpos feats head    deprel deps                            misc
# 390  13   人口     _  NOUN   NN     _   15  compound    _   SpaceAfter=No|Translit=rénkǒu
# 391  14  普查局     _  VERB   VV     _   15  compound    _  SpaceAfter=No|Translit=pǔchájú
#      id form lemma  upos xpos feats head deprel deps                            misc
# 392  15   數據     _  NOUN   NN     _   16  nsubj    _    SpaceAfter=No|Translit=shùjù
# 393  16   顯示     _  VERB   VV     _   37  xcomp    _  SpaceAfter=No|Translit=xiǎnshì
#      id form lemma  upos xpos feats head    deprel deps                             misc
# 396  19    年     _  NOUN  NNB     _   20  obl:tmod    _      SpaceAfter=No|Translit=nián
# 397  20  選舉日     _  VERB   VV     _   26  obl:tmod    _  SpaceAfter=No|Translit=xuǎnjǔrì
#      id form lemma  upos xpos feats head deprel deps                            misc
# 402  25   投票     _  NOUN   NN     _   26  nsubj    _  SpaceAfter=No|Translit=tóupiào
# 403  26   只有     _  VERB   VV     _   37    dep    _   SpaceAfter=No|Translit=zhǐyǒu
#     id form lemma  upos xpos feats head deprel deps                           misc
# 440  6   國家     _  NOUN   NN     _   17  nsubj    _  SpaceAfter=No|Translit=guójiā
# 441  7    用     _  VERB   VV     _   17  advcl    _    SpaceAfter=No|Translit=yòng
#     id form lemma  upos xpos feats head deprel deps                              misc
# 462  3   先生     _  NOUN   NN     _    4  nsubj    _  SpaceAfter=No|Translit=xiānshēng
# 463  4    說     _  VERB   VV     _    0   root    _       SpaceAfter=No|Translit=shuō
#     id form lemma  upos xpos feats head deprel deps                             misc
# 493  1   警方     _  NOUN   NN     _    2  nsubj    _  SpaceAfter=No|Translit=jǐngfāng
# 494  2   表示     _  VERB   VV     _    0   root    _   SpaceAfter=No|Translit=biǎoshì
#      id form lemma  upos xpos feats head deprel deps                           misc
# 501   9    臉     _  NOUN   NN     _   10    obj    _    SpaceAfter=No|Translit=liǎn
# 502  10   按進     _  VERB   VV     _   15  advcl    _  SpaceAfter=No|Translit='ànjìn
#      id form lemma  upos xpos feats head deprel deps                            misc
# 517  25   方式     _  NOUN   NN     _   22    obj    _  SpaceAfter=No|Translit=fāngshì
# 518  26   殺死     _  VERB   VV     _   21  xcomp    _    SpaceAfter=No|Translit=shāsǐ
#     id form lemma  upos xpos feats head deprel deps                           misc
# 543  5   女人     _  NOUN   NN     _    6  nsubj    _   SpaceAfter=No|Translit=nǚrén
# 544  6   開始     _  VERB   VV     _   16    dep    _  SpaceAfter=No|Translit=kāishǐ
#      id form lemma  upos xpos feats head deprel deps                             misc
# 572  16   機構     _  NOUN   NN     _   17    obl    _     SpaceAfter=No|Translit=jīgòu
# 573  17   簽訂     _  VERB   VV     _    0   root    _  SpaceAfter=No|Translit=qiāndìng
#     id form lemma  upos xpos feats head    deprel deps                           misc
# 692  5   最初     _  NOUN   NN     _    6  obl:tmod    _  SpaceAfter=No|Translit=zuìchū
# 693  6   以為     _  VERB   VV     _   18     advcl    _   SpaceAfter=No|Translit=yǐwèi
#     id form lemma  upos xpos feats head deprel deps                            misc
# 694  7   電池     _  NOUN   NN     _    8  nsubj    _  SpaceAfter=No|Translit=diànchí
# 695  8   故障     _  VERB   VV     _   11  csubj    _  SpaceAfter=No|Translit=gùzhàng
#      id form lemma  upos xpos feats head deprel deps                            misc
# 704  17   組件     _  NOUN   NN     _   14    obj    _   SpaceAfter=No|Translit=zǔjiàn
# 705  18   改用     _  VERB   VV     _    0   root    _  SpaceAfter=No|Translit=gǎiyòng
#     id form lemma  upos xpos feats head deprel deps                            misc
# 727  3   手機     _  NOUN   NN     _    4  nsubj    _   SpaceAfter=No|Translit=shǒujī
# 728  4   缺少     _  VERB   VV     _    0   root    _  SpaceAfter=No|Translit=quēshǎo
#     id form lemma  upos xpos feats head deprel deps                          misc
# 730  6    個     _  NOUN  NNB     _   18    clf    _     SpaceAfter=No|Translit=gè
# 731  7    像     _  VERB   VV     _   18   amod    _  SpaceAfter=No|Translit=xiàng
#     id form lemma  upos xpos feats head    deprel deps                             misc
# 747  4   專家     _  NOUN   NN     _    5  compound    _  SpaceAfter=No|Translit=zhuānjiā
# 748  5   警告     _  VERB   VV     _    2     ccomp    _   SpaceAfter=No|Translit=jǐnggào
#     id form lemma  upos xpos feats head deprel deps                            misc
# 751  8   飛機     _  NOUN   NN     _   11  nsubj    _    SpaceAfter=No|Translit=fēijī
# 752  9   飛行     _  VERB   VV     _   11  advcl    _  SpaceAfter=No|Translit=fēixíng
#      id form lemma  upos xpos feats head deprel deps                            misc
# 805   9   乘客     _  NOUN   NN     _   10    obl    _  SpaceAfter=No|Translit=chéngkè
# 806  10   收取     _  VERB   VV     _    7  xcomp    _   SpaceAfter=No|Translit=shōuqǔ
#     id form lemma  upos xpos feats head deprel deps                           misc
# 839  3   時候     _  NOUN   NN     _    2    obj    _  SpaceAfter=No|Translit=shíhou
# 840  4    看     _  VERB   VV     _    0   root    _     SpaceAfter=No|Translit=kàn
#     id form lemma  upos xpos feats head     deprel deps                          misc
# 855  2    項     _  NOUN  NNB     _    7        clf    _  SpaceAfter=No|Translit=xiàng
# 856  3   為期     _  VERB   VV     _    7  acl:relcl    _  SpaceAfter=No|Translit=wèiqī
#      id form lemma  upos xpos feats head deprel deps                          misc
# 886  15   意圖     _  NOUN   NN     _   10   conj    _   SpaceAfter=No|Translit=yìtú
# 887  16   提出     _  VERB   VV     _    0   root    _  SpaceAfter=No|Translit=tíchū
#     id form lemma  upos xpos feats head    deprel deps                            misc
# 894  4   博客     _  NOUN   NN     _    5  compound    _     SpaceAfter=No|Translit=bókè
# 895  5  撰稿人     _  VERB   VV     _    6     nsubj    _  SpaceAfter=No|Translit=撰gǎorén
#      id form lemma  upos xpos feats head deprel deps                         misc
# 943  23    民     _  NOUN   NN     _   24  nsubj    _   SpaceAfter=No|Translit=mín
# 944  24    用     _  VERB   VV     _   25   amod    _  SpaceAfter=No|Translit=yòng
#      id form lemma  upos xpos feats head     deprel deps                             misc
# 948  28   方面     _  NOUN   NN     _   29        obl    _  SpaceAfter=No|Translit=fāngmiàn
# 949  29   展示     _  VERB   VV     _   32  acl:relcl    _   SpaceAfter=No|Translit=zhǎnshì
#      id form lemma  upos xpos feats head deprel deps                        misc
# 963  10    人     _  NOUN   NN     _   14  nsubj    _  SpaceAfter=No|Translit=rén
# 964  11    替     _  VERB   VV     _   14  advcl    _   SpaceAfter=No|Translit=tì
#      id form lemma  upos xpos feats head deprel deps                            misc
# 966  13    人     _  NOUN   NN     _   11    obj    _      SpaceAfter=No|Translit=rén
# 967  14   毀壞     _  VERB   VV     _    6  ccomp    _  SpaceAfter=No|Translit=huǐhuài
#       id form lemma  upos xpos      feats head deprel deps                           misc
# 1007  18   攻擊     _  NOUN   NN          _   19  nsubj    _  SpaceAfter=No|Translit=gōngjī
# 1008  19    令     _  VERB   VV  Voice=Cau    0   root    _    SpaceAfter=No|Translit=lìng
#       id form lemma  upos xpos feats head deprel deps                             misc
# 1010  21   網站     _  NOUN   NN     _   22  nsubj    _  SpaceAfter=No|Translit=wǎngzhàn
# 1011  22   例如     _  VERB   VV     _   34  csubj    _      SpaceAfter=No|Translit=lìrú
#      id form lemma  upos xpos feats head deprel deps                             misc
# 1026  1   分析     _  NOUN   NN     _    2  nsubj    _     SpaceAfter=No|Translit=fēnxī
# 1027  2   表明     _  VERB   VV     _    0   root    _  SpaceAfter=No|Translit=biǎomíng
#      id form lemma  upos xpos feats head deprel deps                            misc
# 1042  3   國家     _  NOUN   NN     _    4  nsubj    _   SpaceAfter=No|Translit=guójiā
# 1043  4   削減     _  VERB   VV     _    6   amod    _  SpaceAfter=No|Translit=xuējiǎn
#       id form lemma  upos xpos feats head deprel deps                               misc
# 1056  17   氣溫     _  NOUN   NN     _   18  nsubj    _       SpaceAfter=No|Translit=qìwēn
# 1057  18   上升     _  VERB   VV     _   15  ccomp    _  SpaceAfter=No|Translit=shàngshēng
#      id form lemma  upos xpos feats head deprel deps                             misc
# 1066  2  科學家     _  NOUN   NN     _    3  nsubj    _  SpaceAfter=No|Translit=kēxuéjiā
# 1067  3    說     _  VERB   VV     _    0   root    _      SpaceAfter=No|Translit=shuō
#      id form lemma  upos xpos feats head    deprel deps                           misc
# 1069  5   目前     _  NOUN   NN     _   15  obl:tmod    _  SpaceAfter=No|Translit=mùqián
# 1070  6   需要     _  VERB   VV     _   15     advcl    _   SpaceAfter=No|Translit=xūyào
#      id form lemma  upos xpos feats head    deprel deps                                         misc
# 1085  2   環境     _  NOUN   NN     _    4  compound    _  Proper=True|SpaceAfter=No|Translit=huánjìng
# 1086  3  規劃署     _  VERB   VV     _    4  compound    _   Proper=True|SpaceAfter=No|Translit=guī劃shǔ
#       id form lemma  upos xpos feats head deprel deps                              misc
# 1098  15   方向     _  NOUN   NN     _   12    obj    _  SpaceAfter=No|Translit=fāngxiàng
# 1099  16   前進     _  VERB   VV     _    8  ccomp    _    SpaceAfter=No|Translit=qiánjìn
#       id form lemma  upos xpos feats head deprel deps                          misc
# 1102  19   協議     _  NOUN   NN     _   20  nsubj    _  SpaceAfter=No|Translit=xiéyì
# 1103  20   提及     _  VERB   VV     _   31    dep    _   SpaceAfter=No|Translit=tíjí
#       id form lemma  upos xpos feats head    deprel deps                                            misc
# 1111  28  基加利     _  NOUN   NN     _   29  compound    _      Proper=True|SpaceAfter=No|Translit=jījiālì
# 1112  29  修正案     _  VERB   VV     _   31     nsubj    _  Proper=True|SpaceAfter=No|Translit=xiūzhèng'àn
#      id form lemma  upos xpos feats head deprel deps                              misc
# 1125  7    年     _  NOUN  NNB     _    8    obl    _       SpaceAfter=No|Translit=nián
# 1126  8   增長     _  VERB   VV     _    0   root    _  SpaceAfter=No|Translit=zēngzhǎng
#      id form lemma  upos xpos feats head deprel deps                          misc
# 1142  8    事     _  NOUN   NN     _    2  appos    _    SpaceAfter=No|Translit=shì
# 1143  9   值得     _  VERB   VV     _   18    dep    _  SpaceAfter=No|Translit=zhíde
#      id form lemma  upos xpos feats head deprel deps                        misc
# 1164  6    月     _  NOUN  NNB     _   10    obl    _  SpaceAfter=No|Translit=yuè
# 1165  7    在     _  VERB   VV     _   10  advcl    _  SpaceAfter=No|Translit=zài
#       id form lemma  upos xpos feats head deprel deps                           misc
# 1167   9   海岸     _  NOUN   NN     _    7    obj    _  SpaceAfter=No|Translit=hǎi'àn
# 1168  10   舉行     _  VERB   VV     _    0   root    _  SpaceAfter=No|Translit=jǔxíng
#      id form lemma  upos xpos feats head     deprel deps                               misc
# 1216  5   種子     _  NOUN   NN     _    6        obl    _     SpaceAfter=No|Translit=zhǒngzi
# 1217  6   長成     _  VERB   VV     _    8  acl:relcl    _  SpaceAfter=No|Translit=zhǎngchéng
#       id form lemma  upos xpos feats head     deprel deps                               misc
# 1232  21   種子     _  NOUN   NN     _   22        obl    _     SpaceAfter=No|Translit=zhǒngzi
# 1233  22   長成     _  VERB   VV     _   24  acl:relcl    _  SpaceAfter=No|Translit=zhǎngchéng
#      id form lemma  upos xpos feats head deprel deps                           misc
# 1245  5   結果     _  NOUN   NN     _    6    obl    _  SpaceAfter=No|Translit=jiéguǒ
# 1246  6   提供     _  VERB   VV     _   41    dep    _  SpaceAfter=No|Translit=tígōng
#       id form lemma  upos xpos feats head     deprel deps                              misc
# 1295  10  老師們     _  NOUN   NN     _    8       conj    _  SpaceAfter=No|Translit=lǎoshīmen
# 1296  11   發來     _  VERB   VV     _   13  acl:relcl    _      SpaceAfter=No|Translit=fālái
#       id  form lemma  upos xpos feats head deprel deps                                  misc
# 1368  10  高激光束     _  NOUN   NN     _    9    obj    _  SpaceAfter=No|Translit=gāojīguāngshù
# 1369  11    進行     _  VERB   VV     _    3  ccomp    _        SpaceAfter=No|Translit=jìnxíng
#      id form lemma  upos xpos feats head    deprel deps                         misc
# 1401  2   事後     _  NOUN   NN     _    3  obl:tmod    _  SpaceAfter=No|Translit=shì後
# 1402  3    問     _  VERB   VV     _    0      root    _   SpaceAfter=No|Translit=wèn
#       id form lemma  upos xpos feats head deprel deps                          misc
# 1430   9    人     _  NOUN   NN     _   10  nsubj    _    SpaceAfter=No|Translit=rén
# 1431  10   覺得     _  VERB   VV     _    8  ccomp    _  SpaceAfter=No|Translit=juéde
#      id form lemma  upos xpos feats head    deprel deps                             misc
# 1493  8   同年     _  NOUN   NN     _   11  obl:tmod    _  SpaceAfter=No|Translit=tóngnián
# 1494  9    在     _  VERB   VV     _   11     advcl    _       SpaceAfter=No|Translit=zài
#      id form lemma  upos xpos feats head deprel deps                         misc
# 1502  3   祖母     _  NOUN   NN     _    4  nsubj    _  SpaceAfter=No|Translit=zǔmǔ
# 1503  4    來     _  VERB   VV     _   25    dep    _   SpaceAfter=No|Translit=lái
#       id form lemma  upos xpos feats head deprel deps                            misc
# 1523  24    月     _  NOUN  NNB     _   25    obl    _      SpaceAfter=No|Translit=yuè
# 1524  25   訪問     _  VERB   VV     _    0   root    _  SpaceAfter=No|Translit=fǎngwèn
#      id form lemma  upos xpos feats head    deprel deps                             misc
# 1554  3   警方     _  NOUN   NN     _    4  compound    _  SpaceAfter=No|Translit=jǐngfāng
# 1555  4  發言人     _  VERB   VV     _    5     nsubj    _  SpaceAfter=No|Translit=fāyánrén
#       id form lemma  upos xpos feats head deprel deps                              misc
# 1573  22   人員     _  NOUN   NN     _   23  nsubj    _    SpaceAfter=No|Translit=rényuán
# 1574  23   傷亡     _  VERB   VV     _   24   amod    _  SpaceAfter=No|Translit=shāngwáng
#       id form lemma  upos xpos feats head deprel deps                            misc
# 1595  19   事故     _  NOUN   NN     _   20  nsubj    _    SpaceAfter=No|Translit=shìgù
# 1596  20   發生     _  VERB   VV     _   23  xcomp    _  SpaceAfter=No|Translit=fāshēng
#       id form lemma  upos xpos feats head     deprel deps                            misc
# 1611  10   大群     _  NOUN  NNB     _   17        clf    _    SpaceAfter=No|Translit=dàqún
# 1612  11   自稱     _  VERB   VV     _   17  acl:relcl    _  SpaceAfter=No|Translit=zìchēng
#      id form lemma  upos xpos feats head deprel deps                            misc
# 1627  2   人員     _  NOUN   NN     _   10  nsubj    _  SpaceAfter=No|Translit=rényuán
# 1628  3   付出     _  VERB   VV     _   10    acl    _    SpaceAfter=No|Translit=fùchū
#       id form lemma  upos xpos feats head     deprel deps                           misc
# 1635  10   研究     _  NOUN   NN     _    0       root    _  SpaceAfter=No|Translit=yánjiū
# 1636  11   發展     _  VERB   VV     _   16  acl:relcl    _  SpaceAfter=No|Translit=fāzhǎn
#       id form lemma  upos xpos feats head    deprel deps                           misc
# 1638  13   激素     _  NOUN   NN     _   14  compound    _    SpaceAfter=No|Translit=jīsù
# 1639  14  避孕藥     _  VERB   VV     _   11       obj    _  SpaceAfter=No|Translit=bì孕yào
#      id form lemma  upos xpos feats head deprel deps                            misc
# 1685  2   人員     _  NOUN   NN     _    3  nsubj    _  SpaceAfter=No|Translit=rényuán
# 1686  3    說     _  VERB   VV     _    0   root    _     SpaceAfter=No|Translit=shuō
#      id form lemma  upos xpos feats head deprel deps                            misc
# 1702  2   分析     _  NOUN   NN     _    3  nsubj    _    SpaceAfter=No|Translit=fēnxī
# 1703  3   顯示     _  VERB   VV     _    0   root    _  SpaceAfter=No|Translit=xiǎnshì
#       id form lemma  upos xpos feats head deprel deps                                       misc
# 1755  10   醫院     _  NOUN   NN     _    4    obj    _  Proper=True|SpaceAfter=No|Translit=yīyuàn
# 1756  11   接受     _  VERB   VV     _    0   root    _             SpaceAfter=No|Translit=jiēshòu
#      id form lemma  upos xpos feats head deprel deps                            misc
# 1761  2   掃描     _  NOUN   NN     _    3  nsubj    _  SpaceAfter=No|Translit=sǎomiáo
# 1762  3   顯示     _  VERB   VV     _   16    dep    _  SpaceAfter=No|Translit=xiǎnshì
#      id form lemma  upos xpos feats head    deprel deps                            misc
# 1831  3   上午     _  NOUN   NN     _    4  obl:tmod    _  SpaceAfter=No|Translit=shàngwǔ
# 1832  4    有     _  VERB   VV     _   12     xcomp    _      SpaceAfter=No|Translit=yǒu
#      id form lemma  upos xpos feats head deprel deps                             misc
# 1833  5   照片     _  NOUN   NN     _    6  nsubj    _  SpaceAfter=No|Translit=zhàopiàn
# 1834  6   發布     _  VERB   VV     _    4  ccomp    _      SpaceAfter=No|Translit=fābù
#       id form lemma  upos xpos feats head deprel deps                             misc
# 1839  11   警方     _  NOUN   NN     _   12  nsubj    _  SpaceAfter=No|Translit=jǐngfāng
# 1840  12   表示     _  VERB   VV     _    0   root    _   SpaceAfter=No|Translit=biǎoshì
#       id form lemma  upos xpos feats head deprel deps                        misc
# 1859  31    人     _  NOUN   NN     _   32    obl    _  SpaceAfter=No|Translit=rén
# 1860  32    有     _  VERB   VV     _   12  ccomp    _  SpaceAfter=No|Translit=yǒu
#      id form lemma  upos xpos feats head deprel deps                             misc
# 1867  2   警方     _  NOUN   NN     _   14  nsubj    _  SpaceAfter=No|Translit=jǐngfāng
# 1868  3    說     _  VERB   VV     _   14  advcl    _      SpaceAfter=No|Translit=shuō
#       id form lemma  upos xpos feats head deprel deps                                     misc
# 1910  21   地區     _  NOUN   NN     _   18  xcomp    _  Proper=True|SpaceAfter=No|Translit=deqū
# 1911  22    有     _  VERB   VV     _    3  ccomp    _               SpaceAfter=No|Translit=yǒu
#       id form lemma  upos xpos feats head deprel deps                            misc
# 1931  14   牢房     _  NOUN   NN     _   13    obj    _  SpaceAfter=No|Translit=láofáng
# 1932  15   出席     _  VERB   VV     _   12  xcomp    _    SpaceAfter=No|Translit=chūxí
#      id form lemma  upos xpos feats head deprel deps                            misc
# 1942  6   協會     _  NOUN   NN     _    7  nsubj    _   SpaceAfter=No|Translit=xiéhuì
# 1943  7   表示     _  VERB   VV     _    0   root    _  SpaceAfter=No|Translit=biǎoshì
#      id form lemma  upos xpos feats head    deprel deps                             misc
# 1969  7   省內     _  NOUN   NN     _    8  compound    _  SpaceAfter=No|Translit=shěngnèi
# 1970  8  代理人     _  VERB   VV     _    6       obj    _  SpaceAfter=No|Translit=dàilǐrén
#      id form lemma  upos xpos feats head     deprel deps                          misc
# 1992  6   代理     _  NOUN   NN     _    7        obl    _  SpaceAfter=No|Translit=dàilǐ
# 1993  7   徵收     _  VERB   VV     _   10  acl:relcl    _  SpaceAfter=No|Translit=徵shōu
#       id form lemma  upos xpos feats head deprel deps                           misc
# 2080   9   任期     _  NOUN   NN     _   10  nsubj    _   SpaceAfter=No|Translit=rènqī
# 2081  10   結束     _  VERB   VV     _    4  ccomp    _  SpaceAfter=No|Translit=jiéshù
#       id form lemma  upos xpos feats head deprel deps                             misc
# 2089  18   條款     _  NOUN   NN     _   13    obj    _  SpaceAfter=No|Translit=tiáokuǎn
# 2090  19   退出     _  VERB   VV     _    0   root    _    SpaceAfter=No|Translit=tuìchū
#       id form lemma  upos xpos      feats head deprel deps                             misc
# 2120  28   性情     _  NOUN   NN          _   29  nsubj    _  SpaceAfter=No|Translit=xìngqíng
# 2121  29    使     _  VERB   VV  Voice=Cau    0   root    _       SpaceAfter=No|Translit=shǐ
#       id form lemma  upos xpos feats head deprel deps                           misc
# 2181  24   安慰     _  NOUN   NN     _   25  nsubj    _  SpaceAfter=No|Translit='ānwèi
# 2182  25    是     _  VERB   VC     _   21  ccomp    _     SpaceAfter=No|Translit=shì
#      id form lemma  upos xpos feats head deprel deps                             misc
# 2192  4   疼痛     _  NOUN   NN     _    5  nsubj    _  SpaceAfter=No|Translit=téngtòng
# 2193  5   折磨     _  VERB   VV     _    3  ccomp    _     SpaceAfter=No|Translit=zhémó
#       id form lemma  upos xpos feats head deprel deps                                       misc
# 2212  24   新聞     _  NOUN   NN     _   25    obl    _  Proper=True|SpaceAfter=No|Translit=xīnwén
# 2213  25    說     _  VERB   VV     _    0   root    _                SpaceAfter=No|Translit=shuō
#      id form lemma  upos xpos feats head deprel deps                            misc
# 2218  4   醫生     _  NOUN   NN     _    5  nsubj    _  SpaceAfter=No|Translit=yīshēng
# 2219  5   沒有     _  VERB   VV     _   10    dep    _   SpaceAfter=No|Translit=méiyǒu
#      id form lemma  upos xpos feats head deprel deps                               misc
# 2236  8  原住民     _  NOUN   NN     _    9    obl    _  SpaceAfter=No|Translit=yuánzhùmín
# 2237  9   進行     _  VERB   VV     _   13    obl    _     SpaceAfter=No|Translit=jìnxíng
#       id form lemma  upos xpos feats head deprel deps                          misc
# 2240  12    事     _  NOUN   NN     _    9  appos    _    SpaceAfter=No|Translit=shì
# 2241  13   提出     _  VERB   VV     _    2  ccomp    _  SpaceAfter=No|Translit=tíchū
#       id form lemma  upos xpos feats head deprel deps                           misc
# 2244  16    人     _  NOUN   NN     _   17  nsubj    _     SpaceAfter=No|Translit=rén
# 2245  17   擔憂     _  VERB   VV     _   15  ccomp    _  SpaceAfter=No|Translit=dānyōu
#      id form lemma  upos xpos feats head deprel deps                            misc
# 2318  4   預算     _  NOUN   NN     _    5  nsubj    _   SpaceAfter=No|Translit=yùsuàn
# 2319  5   超過     _  VERB   VV     _   11    dep    _  SpaceAfter=No|Translit=chāoguò
#       id form lemma  upos xpos feats head deprel deps                             misc
# 2324  10   員工     _  NOUN   NN     _   11  nsubj    _  SpaceAfter=No|Translit=yuángōng
# 2325  11   超過     _  VERB   VV     _    0   root    _   SpaceAfter=No|Translit=chāoguò
#       id form lemma  upos xpos feats head deprel deps                               misc
# 2383   9  委員會     _  NOUN   NN     _   10  nsubj    _  SpaceAfter=No|Translit=wěiyuánhuì
# 2384  10   調查     _  VERB   VV     _    8  ccomp    _     SpaceAfter=No|Translit=diàochá
#       id form lemma  upos xpos feats head deprel deps                             misc
# 2385  11   聯邦     _  NOUN   NN     _   12  nsubj    _  SpaceAfter=No|Translit=liánbāng
# 2386  12   贊助     _  VERB   VV     _   13   amod    _    SpaceAfter=No|Translit=zànzhù
#       id form lemma  upos xpos feats head deprel deps                           misc
# 2401  27   信心     _  NOUN   NN     _   22    obj    _  SpaceAfter=No|Translit=xìnxīn
# 2402  28    是     _  VERB   VC     _   16  ccomp    _     SpaceAfter=No|Translit=shì
#       id form lemma  upos xpos feats head deprel deps                            misc
# 2427  20   警察     _  NOUN   NN     _   21  nsubj    _  SpaceAfter=No|Translit=jǐngchá
# 2428  21   監視     _  VERB   VV     _   22   amod    _  SpaceAfter=No|Translit=jiānshì
#      id form lemma  upos xpos feats head deprel deps                              misc
# 2445  8   政黨     _  NOUN   NN     _    6   conj    _  SpaceAfter=No|Translit=zhèngdǎng
# 2446  9   提供     _  VERB   VV     _   15  xcomp    _     SpaceAfter=No|Translit=tígōng
#       id form lemma  upos xpos feats head deprel deps                            misc
# 2457  20   組織     _  NOUN   NN     _   18   conj    _    SpaceAfter=No|Translit=zǔzhī
# 2458  21   優先     _  VERB   VV     _   22  advcl    _  SpaceAfter=No|Translit=yōuxiān
#       id form lemma  upos xpos feats head    deprel deps                                misc
# 2467  30   進入     _  NOUN   NN     _   31  compound    _        SpaceAfter=No|Translit=jìnrù
# 2468  31  優先權     _  VERB   VV     _   25      conj    _  SpaceAfter=No|Translit=yōuxiānquán
#       id form lemma  upos xpos feats head    deprel deps                           misc
# 2517  10    月     _  NOUN   NN     _   11  obl:tmod    _     SpaceAfter=No|Translit=yuè
# 2518  11   報導     _  VERB   VV     _    0      root    _  SpaceAfter=No|Translit=bàodǎo
#      id form lemma  upos xpos feats head    deprel deps                           misc
# 2530  6   最近     _  NOUN   NN     _    7  obl:tmod    _  SpaceAfter=No|Translit=zuìjìn
# 2531  7   推出     _  VERB   VV     _    3     ccomp    _  SpaceAfter=No|Translit=tuīchū
#       id form lemma  upos xpos feats head deprel deps                             misc
# 2542  18   客戶     _  NOUN   NN     _   19  nsubj    _      SpaceAfter=No|Translit=kèhù
# 2543  19   監控     _  VERB   VV     _   17  ccomp    _  SpaceAfter=No|Translit=jiānkòng
#       id form lemma  upos xpos feats head    deprel deps                                 misc
# 2545  21   數據     _  NOUN   NN     _   22  compound    _         SpaceAfter=No|Translit=shùjù
# 2546  22  使用量     _  VERB   VV     _   19       obj    _  SpaceAfter=No|Translit=shǐyòngliàng
#       id form lemma  upos xpos feats head deprel deps                           misc
# 2608  23   夜晚     _  NOUN   NN     _   24    obl    _   SpaceAfter=No|Translit=yèwǎn
# 2609  24   入睡     _  VERB   VV     _   20  ccomp    _  SpaceAfter=No|Translit=rùshuì
#       id form lemma  upos xpos feats head deprel deps                         misc
# 2627  42   大麻     _  NOUN   NN     _   43  nsubj    _  SpaceAfter=No|Translit=dàmá
# 2628  43    是     _  VERB   VC     _   37  ccomp    _   SpaceAfter=No|Translit=shì
#       id form lemma  upos xpos feats head     deprel deps                         misc
# 2643  10   大麻     _  NOUN   NN     _   11      nsubj    _  SpaceAfter=No|Translit=dàmá
# 2644  11    作     _  VERB   VV     _   27  acl:relcl    _   SpaceAfter=No|Translit=zuò
#      id form lemma  upos xpos feats head deprel deps                              misc
# 2671  3   人體     _  NOUN   NN     _    4  nsubj    _      SpaceAfter=No|Translit=réntǐ
# 2672  4   生產     _  VERB   VV     _    7  csubj    _  SpaceAfter=No|Translit=shēngchǎn
#       id form lemma  upos xpos feats head deprel deps                              misc
# 2683  15  蛋白質     _  NOUN   NN     _   16  nsubj    _  SpaceAfter=No|Translit=dànbáizhì
# 2684  16   負責     _  VERB   VV     _    0   root    _       SpaceAfter=No|Translit=fùzé
#       id form lemma  upos xpos feats head       deprel deps                              misc
# 2686  18   氧氣     _  NOUN   NN     _   19  obl:patient    _     SpaceAfter=No|Translit=yǎngqì
# 2687  19   傳送     _  VERB   VV     _   16        xcomp    _  SpaceAfter=No|Translit=chuánsòng
#      id form lemma  upos xpos feats head deprel deps                           misc
# 2704  2   可能     _  NOUN   NN     _    1    obj    _  SpaceAfter=No|Translit=kěnéng
# 2705  3    有     _  VERB   VV     _   23    dep    _     SpaceAfter=No|Translit=yǒu
#      id form lemma  upos xpos feats head deprel deps                             misc
# 2732  6   方針     _  NOUN   NN     _    7  nsubj    _  SpaceAfter=No|Translit=fāngzhēn
# 2733  7   意味     _  VERB   VV     _    0   root    _     SpaceAfter=No|Translit=yìwèi
#       id form lemma  upos xpos feats head deprel deps                          misc
# 2755  16   孩子     _  NOUN   NN     _   28  nsubj    _  SpaceAfter=No|Translit=háizi
# 2756  17   具有     _  VERB   VV     _   28  advcl    _  SpaceAfter=No|Translit=jùyǒu
#       id form lemma  upos xpos feats head     deprel deps                          misc
# 2793  13   尾骨     _  NOUN   NN     _   14        obl    _  SpaceAfter=No|Translit=wěigǔ
# 2794  14    長     _  VERB   VV     _   17  acl:relcl    _  SpaceAfter=No|Translit=zhǎng
#       id form lemma  upos xpos feats head     deprel deps                           misc
# 2843  23   文壇     _  NOUN   NN     _   24        obl    _    SpaceAfter=No|Translit=wén壇
# 2844  24   留下     _  VERB   VV     _   30  acl:relcl    _  SpaceAfter=No|Translit=liúxià
#      id form lemma  upos xpos feats head deprel deps                         misc
# 2853  2    人     _  NOUN   NN     _    3  nsubj    _   SpaceAfter=No|Translit=rén
# 2854  3    懂     _  VERB   VV     _    1  ccomp    _  SpaceAfter=No|Translit=dǒng
#       id form lemma  upos xpos feats head deprel deps                             misc
# 2890  20  女孩們     _  NOUN   NN     _   21  nsubj    _  SpaceAfter=No|Translit=nǚháimen
# 2891  21   擁抱     _  VERB   VV     _   19  ccomp    _   SpaceAfter=No|Translit=yōngbào
#      id form lemma  upos xpos feats head deprel deps                              misc
# 2901  3   呼聲     _  NOUN   NN     _    4  nsubj    _    SpaceAfter=No|Translit=hūshēng
# 2902  4   傳遍     _  VERB   VV     _    9    dep    _  SpaceAfter=No|Translit=chuánbiàn
#      id form lemma  upos xpos feats head deprel deps                         misc
# 2953  5   目的     _  NOUN   NN     _    6  nsubj    _  SpaceAfter=No|Translit=mùde
# 2954  6    是     _  VERB   VC     _    0   root    _   SpaceAfter=No|Translit=shì
#      id form lemma  upos xpos feats head deprel deps                            misc
# 3008  1   碎片     _  NOUN   NN     _   23  nsubj    _  SpaceAfter=No|Translit=suìpiàn
# 3009  2   圍繞     _  VERB   VV     _    7  advcl    _   SpaceAfter=No|Translit=wéirào
#      id form lemma  upos xpos feats head deprel deps                              misc
# 3013  6   赤道     _  NOUN   NN     _    2    obj    _     SpaceAfter=No|Translit=chìdào
# 3014  7   形成     _  VERB   VV     _   23  advcl    _  SpaceAfter=No|Translit=xíngchéng
#       id form lemma  upos xpos feats head deprel deps                            misc
# 3054  12    人     _  NOUN   NN     _   13  nsubj    _      SpaceAfter=No|Translit=rén
# 3055  13   轟炸     _  VERB   VV     _   11  ccomp    _  SpaceAfter=No|Translit=hōngzhà
#      id form lemma  upos xpos feats head deprel deps                            misc
# 3064  5    年     _  NOUN  NNB     _    6    obl    _     SpaceAfter=No|Translit=nián
# 3065  6   通過     _  VERB   VV     _   20  xcomp    _  SpaceAfter=No|Translit=tōngguò
#       id  form lemma  upos xpos feats head deprel deps                                    misc
# 3122  10   不一致     _  NOUN   NN     _   17  nsubj    _          SpaceAfter=No|Translit=bùyīzhì
# 3123  11  似曾相識     _  VERB   VV     _   17  advcl    _  SpaceAfter=No|Translit=shìcéngxiāngshi
#      id  form lemma  upos xpos feats head deprel deps                                 misc
# 3132  2  經濟學家     _  NOUN   NN     _    3  nsubj    _  SpaceAfter=No|Translit=jīngjìxuéjiā
# 3133  3    告誡     _  VERB   VV     _    0   root    _        SpaceAfter=No|Translit=gàojiè
#       id form lemma  upos xpos feats head deprel deps                              misc
# 3172  24   發展     _  NOUN   NN     _   25  nsubj    _     SpaceAfter=No|Translit=fāzhǎn
# 3173  25   產生     _  VERB   VV     _    0   root    _  SpaceAfter=No|Translit=chǎnshēng
#       id form lemma  upos xpos feats head deprel deps                            misc
# 3305   9   程度     _  NOUN   NN     _   10  nsubj    _  SpaceAfter=No|Translit=chéngdù
# 3306  10   加劇     _  VERB   VV     _    1  ccomp    _    SpaceAfter=No|Translit=jiājù
#       id form lemma  upos xpos feats head deprel deps                           misc
# 3314  18    人     _  NOUN   NN     _   19  nsubj    _     SpaceAfter=No|Translit=rén
# 3315  19   擔憂     _  VERB   VV     _   17  ccomp    _  SpaceAfter=No|Translit=dānyōu
#       id form lemma  upos xpos feats head deprel deps                           misc
# 3317  21   威脅     _  NOUN   NN     _   22  nsubj    _  SpaceAfter=No|Translit=wēixié
# 3318  22   困擾     _  VERB   VV     _    0   root    _  SpaceAfter=No|Translit=kùnrǎo
#      id form lemma  upos xpos feats head deprel deps                          misc
# 3326  5    種     _  NOUN  NNB     _   13    clf    _  SpaceAfter=No|Translit=zhǒng
# 3327  6    有     _  VERB   VV     _   11  advcl    _    SpaceAfter=No|Translit=yǒu
#      id form lemma  upos xpos feats head deprel deps                             misc
# 3338  3   廣告     _  NOUN   NN     _    4  nsubj    _  SpaceAfter=No|Translit=guǎnggào
# 3339  4   結束     _  VERB   VV     _    0   root    _    SpaceAfter=No|Translit=jiéshù
#       id form lemma  upos xpos feats head  deprel deps                         misc
# 3377  15    家     _  NOUN   NN     _   16  advmod    _   SpaceAfter=No|Translit=jiā
# 3378  16    用     _  VERB   VV     _   17    amod    _  SpaceAfter=No|Translit=yòng
#       id form lemma  upos xpos feats head     deprel deps                            misc
# 3379  17  筆記本     _  NOUN   NN     _   14        obj    _  SpaceAfter=No|Translit=bǐjìběn
# 3380  18   錄製     _  VERB   VV     _   30  acl:relcl    _      SpaceAfter=No|Translit=lù製
#       id form lemma  upos xpos feats head       deprel deps                            misc
# 3413  20   系統     _  NOUN   NN     _   21  obl:patient    _   SpaceAfter=No|Translit=xìtǒng
# 3414  21   添加     _  VERB   VV     _    0         root    _  SpaceAfter=No|Translit=tiānjiā
#      id form lemma  upos xpos feats head deprel deps                              misc
# 3426  3   複興     _  NOUN   NN     _    4  nsubj    _     SpaceAfter=No|Translit=fùxìng
# 3427  4   強調     _  VERB   VV     _   26    dep    _  SpaceAfter=No|Translit=qiángdiào
#      id form lemma  upos xpos feats head       deprel deps                           misc
# 3455  5   權力     _  NOUN   NN     _    6  obl:patient    _  SpaceAfter=No|Translit=quánlì
# 3456  6   授予     _  VERB   VV     _   13        csubj    _  SpaceAfter=No|Translit=shòuyǔ
#       id form lemma  upos xpos feats head    deprel deps                          misc
# 3476  12    月     _  NOUN   NN     _   15  obl:tmod    _    SpaceAfter=No|Translit=yuè
# 3477  13   熬夜     _  VERB   VV     _   15     advcl    _  SpaceAfter=No|Translit='áoyè
#      id form lemma  upos xpos feats head deprel deps                                         misc
# 3528  5  基金會     _  NOUN   NN     _    6  nsubj    _  Proper=True|SpaceAfter=No|Translit=jījīnhuì
# 3529  6   發布     _  VERB   VV     _   26  advcl    _                  SpaceAfter=No|Translit=fābù
#       id form lemma  upos xpos feats head     deprel deps                           misc
# 3541  18   風格     _  NOUN   NN     _   19      nsubj    _  SpaceAfter=No|Translit=fēnggé
# 3542  19    似     _  VERB   VV     _   22  acl:relcl    _     SpaceAfter=No|Translit=shì
#      id form lemma  upos xpos feats head  deprel deps                            misc
# 3603  3    次     _  NOUN  NNB     _    4  advmod    _       SpaceAfter=No|Translit=cì
# 3604  4   展出     _  VERB   VV     _   17   csubj    _  SpaceAfter=No|Translit=zhǎnchū
#      id form lemma  upos xpos feats head deprel deps                           misc
# 3630  1   選區     _  NOUN   NN     _    2  nsubj    _  SpaceAfter=No|Translit=xuǎnqū
# 3631  2    位     _  VERB   VV     _   10    dep    _     SpaceAfter=No|Translit=wèi
#       id form lemma  upos xpos feats head deprel deps                            misc
# 3638   9   選民     _  NOUN   NN     _   10  nsubj    _  SpaceAfter=No|Translit=xuǎnmín
# 3639  10    有     _  VERB   VV     _    0   root    _      SpaceAfter=No|Translit=yǒu
#       id form lemma  upos xpos feats head deprel deps                           misc
# 3665   9    日     _  NOUN  NNB     _   10    obl    _      SpaceAfter=No|Translit=rì
# 3666  10   參賽     _  VERB   VV     _   13    dep    _  SpaceAfter=No|Translit=cānsài
#       id  form lemma  upos xpos feats head deprel deps                               misc
# 3731   9    事件     _  NOUN   NN     _   10    obl    _     SpaceAfter=No|Translit=shìjiàn
# 3732  10  處之泰然     _  VERB   VV     _   15  advcl    _  SpaceAfter=No|Translit=chùzhī泰rán
#      id form lemma  upos xpos feats head deprel deps                              misc
# 3742  4   船員     _  NOUN   NN     _    5  nsubj    _  SpaceAfter=No|Translit=chuányuán
# 3743  5    在     _  VERB   VV     _    0   root    _        SpaceAfter=No|Translit=zài
#      id form lemma  upos xpos feats head      deprel deps                            misc
# 3752  7   年代     _  NOUN  NNB     _    8       nsubj    _  SpaceAfter=No|Translit=niándài
# 3753  8   久遠     _  VERB   VV     _    6  dislocated    _  SpaceAfter=No|Translit=jiǔyuǎn
#      id form lemma  upos xpos        feats head      deprel deps                           misc
# 3763  1   人們     _  NOUN   NN  Number=Plur    5  nsubj:pass    _  SpaceAfter=No|Translit=rénmen
# 3764  2    在     _  VERB   VV            _    5       advcl    _     SpaceAfter=No|Translit=zài
#       id form lemma  upos xpos feats head    deprel deps                             misc
# 3779  10   柴油     _  NOUN   NN     _   11  compound    _   SpaceAfter=No|Translit=cháiyóu
# 3780  11  發電機     _  VERB   VV     _   12     nsubj    _  SpaceAfter=No|Translit=fādiànjī
#       id form lemma  upos xpos feats head deprel deps                                        misc
# 3800  10   電台     _  NOUN   NN     _   11    obl    _  Proper=True|SpaceAfter=No|Translit=diàntái
# 3801  11   工作     _  VERB   VV     _    0   root    _              SpaceAfter=No|Translit=gōngzuò
#       id form lemma  upos xpos      feats head     deprel deps                         misc
# 3826  12    行     _  NOUN  NNB          _   17        clf    _  SpaceAfter=No|Translit=xíng
# 3827  13    讓     _  VERB   VV  Voice=Cau   17  acl:relcl    _  SpaceAfter=No|Translit=ràng
#       id form lemma  upos xpos feats head deprel deps                         misc
# 3844  30   資格     _  NOUN   NN     _   29    obj    _  SpaceAfter=No|Translit=zīgé
# 3845  31    做     _  VERB   VV     _   24  ccomp    _   SpaceAfter=No|Translit=zuò
#       id form lemma  upos xpos feats head deprel deps                           misc
# 3941  10   別人     _  NOUN   NN     _   11  nsubj    _  SpaceAfter=No|Translit=biérén
# 3942  11    沖     _  VERB   VV     _   14  csubj    _   SpaceAfter=No|Translit=chōng
#      id form lemma  upos xpos feats head     deprel deps                              misc
# 3955  5    個     _  NOUN  NNB     _    8        clf    _         SpaceAfter=No|Translit=gè
# 3956  6   朝上     _  VERB   VV     _    8  acl:relcl    _  SpaceAfter=No|Translit=cháoshàng
#       id form lemma  upos xpos feats head       deprel deps                            misc
# 3961  11   小球     _  NOUN   NN     _   13  obl:patient    _  SpaceAfter=No|Translit=xiǎoqiú
# 3962  12   彈來     _  VERB   VV     _   13        advcl    _   SpaceAfter=No|Translit=dànlái
#       id form lemma  upos xpos feats head deprel deps                            misc
# 3991  11   現在     _  NOUN   NN     _   12    obl    _  SpaceAfter=No|Translit=xiànzài
# 3992  12   變得     _  VERB   VV     _    8  ccomp    _   SpaceAfter=No|Translit=biànde
#       id form lemma  upos xpos feats head deprel deps                           misc
# 3995  15    人     _  NOUN   NN     _   16  nsubj    _     SpaceAfter=No|Translit=rén
# 3996  16   擔憂     _  VERB   VV     _   14  ccomp    _  SpaceAfter=No|Translit=dānyōu
#      id form lemma  upos xpos feats head deprel deps                              misc
# 4005  5   傾向     _  NOUN   NN     _    6  nsubj    _  SpaceAfter=No|Translit=qīngxiàng
# 4006  6   著稱     _  VERB   VV     _    3  ccomp    _   SpaceAfter=No|Translit=zhechēng
#       id form lemma  upos xpos feats head     deprel deps                           misc
# 4045  14   系列     _  NOUN   NN     _   21   compound    _   SpaceAfter=No|Translit=xìliè
# 4046  15   下配     _  VERB   VV     _   21  acl:relcl    _  SpaceAfter=No|Translit=xiàpèi
#       id form lemma  upos xpos feats head deprel deps                              misc
# 4068  14   政權     _  NOUN   NN     _   11   conj    _  SpaceAfter=No|Translit=zhèngquán
# 4069  15   分開     _  VERB   VV     _   17  advcl    _     SpaceAfter=No|Translit=fēnkāi
#      id form lemma  upos xpos feats head deprel deps                            misc
# 4074  2   角落     _  NOUN   NN     _    3  nsubj    _  SpaceAfter=No|Translit=jiǎoluò
# 4075  3    有     _  VERB   VV     _    1  ccomp    _      SpaceAfter=No|Translit=yǒu
#      id form lemma  upos xpos feats head     deprel deps                        misc
# 4077  5    個     _  NOUN  NNB     _   17        clf    _   SpaceAfter=No|Translit=gè
# 4078  6    戴     _  VERB   VV     _   17  acl:relcl    _  SpaceAfter=No|Translit=dài
#      id form lemma  upos xpos feats head  deprel deps                         misc
# 4164  5   一起     _  NOUN   NN     _    6  advmod    _  SpaceAfter=No|Translit=yīqǐ
# 4165  6    看     _  VERB   VV     _   20     dep    _   SpaceAfter=No|Translit=kàn
#       id form lemma  upos xpos feats head    deprel deps                            misc
# 4193  12   性別     _  NOUN   NN     _   13  compound    _  SpaceAfter=No|Translit=xìngbié
# 4194  13  歧視者     _  VERB   VV     _   10      conj    _  SpaceAfter=No|Translit=歧shìzhě
#      id form lemma  upos xpos feats head deprel deps                          misc
# 4212  5    人     _  NOUN   NN     _    8  nsubj    _    SpaceAfter=No|Translit=rén
# 4213  6    轉     _  VERB   VV     _    8  advcl    _  SpaceAfter=No|Translit=zhuǎn
#       id form lemma  upos xpos feats head deprel deps                         misc
# 4222  15   借貸     _  NOUN   NN     _   16  nsubj    _  SpaceAfter=No|Translit=jiè貸
# 4223  16    是     _  VERB   VC     _   30  advcl    _   SpaceAfter=No|Translit=shì
#      id form lemma  upos xpos feats head deprel deps                          misc
# 4244  3   理由     _  NOUN   NN     _    4  nsubj    _  SpaceAfter=No|Translit=lǐyóu
# 4245  4    是     _  VERB   VC     _    0   root    _    SpaceAfter=No|Translit=shì
#       id form lemma  upos xpos feats head deprel deps                            misc
# 4321  16   賬戶     _  NOUN   NN     _   17    obl    _      SpaceAfter=No|Translit=賬hù
# 4322  17   添加     _  VERB   VV     _   26    dep    _  SpaceAfter=No|Translit=tiānjiā
#       id form lemma  upos xpos feats head deprel deps                           misc
# 4352  16   時候     _  NOUN   NN     _   17    obl    _  SpaceAfter=No|Translit=shíhou
# 4353  17   拿到     _  VERB   VV     _    0   root    _   SpaceAfter=No|Translit=nádào
# ...
#       id form lemma  upos xpos feats head deprel deps                          misc
# 20212  2   島嶼     _  NOUN   NN     _    3  nsubj    _  SpaceAfter=No|Translit=dǎoyǔ
# 20213  3    位     _  VERB   VV     _   13    dep    _    SpaceAfter=No|Translit=wèi
#        id form lemma  upos xpos feats head deprel deps                             misc
# 20222  12   斷層     _  NOUN   NN     _   13  nsubj    _  SpaceAfter=No|Translit=duàncéng
# 20223  13    是     _  VERB   VC     _    0   root    _       SpaceAfter=No|Translit=shì
#        id form lemma  upos xpos feats head deprel deps                                        misc
# 20229  19   板塊     _  NOUN   NN     _   16   conj    _  Proper=True|SpaceAfter=No|Translit=bǎnkuài
# 20230  20   碰撞     _  VERB   VV     _   21  xcomp    _           SpaceAfter=No|Translit=pèngzhuàng
#       id form lemma  upos xpos feats head     deprel deps                           misc
# 20235  2    項     _  NOUN  NNB     _    8        clf    _   SpaceAfter=No|Translit=xiàng
# 20236  3   支持     _  VERB   VV     _    8  acl:relcl    _  SpaceAfter=No|Translit=zhīchí
#        id form lemma  upos xpos feats head deprel deps                             misc
# 20260   9   旁邊     _  NOUN   NN     _   10  nsubj    _  SpaceAfter=No|Translit=pángbiān
# 20261  10    建     _  VERB   VV     _    4  ccomp    _      SpaceAfter=No|Translit=jiàn
#        id form lemma  upos xpos feats head deprel deps                          misc
# 20286  15   大火     _  NOUN   NN     _   16  nsubj    _  SpaceAfter=No|Translit=dàhuǒ
# 20287  16   吞噬     _  VERB   VV     _   30    dep    _   SpaceAfter=No|Translit=tūn噬
#       id form lemma  upos xpos feats head    deprel deps                               misc
# 20363  5   手工     _  NOUN   NN     _    6  compound    _    SpaceAfter=No|Translit=shǒugōng
# 20364  6  加工品     _  VERB   VV     _    8     nsubj    _  SpaceAfter=No|Translit=jiāgōngpǐn
#       id form lemma  upos xpos feats head deprel deps                           misc
# 20403  6   作家     _  NOUN   NN     _   10  nsubj    _  SpaceAfter=No|Translit=zuòjiā
# 20404  7    用     _  VERB   VV     _   10  advcl    _    SpaceAfter=No|Translit=yòng
#        id form lemma  upos xpos feats head deprel deps                             misc
# 20420   9   挑戰     _  NOUN   NN     _    6    obj    _  SpaceAfter=No|Translit=tiāozhàn
# 20421  10    轉     _  VERB   VV     _   12  advcl    _     SpaceAfter=No|Translit=zhuǎn
#       id form lemma  upos xpos feats head    deprel deps                           misc
# 20431  3   期間     _  NOUN   NN     _    4  obl:tmod    _  SpaceAfter=No|Translit=qījiān
# 20432  4   只有     _  VERB   VV     _   13       dep    _  SpaceAfter=No|Translit=zhǐyǒu
#       id form lemma  upos xpos feats head deprel deps                           misc
# 20435  7   爵位     _  NOUN   NN     _    8  nsubj    _    SpaceAfter=No|Translit=爵wèi
# 20436  8   存在     _  VERB   VV     _    4  ccomp    _  SpaceAfter=No|Translit=cúnzài
#        id form lemma  upos xpos feats head deprel deps                          misc
# 20440  12   爵位     _  NOUN   NN     _   13  nsubj    _   SpaceAfter=No|Translit=爵wèi
# 20441  13   具有     _  VERB   VV     _    0   root    _  SpaceAfter=No|Translit=jùyǒu
#       id form lemma  upos xpos feats head deprel deps                                   misc
# 20453  7    次     _  NOUN  NNB     _   11    clf    _  Proper=True|SpaceAfter=No|Translit=cì
# 20454  8    反     _  VERB   VV     _   10   amod    _             SpaceAfter=No|Translit=fǎn
#        id  form lemma  upos xpos feats head deprel deps                                  misc
# 20466  20    軍官     _  NOUN   NN     _   21  nsubj    _        SpaceAfter=No|Translit=jūnguān
# 20467  21  嶄露頭角     _  VERB   VV     _   25    dep    _  SpaceAfter=No|Translit=zhǎnlùtóujiǎo
#        id form lemma  upos xpos      feats head deprel deps                            misc
# 20487  13   勝利     _  NOUN   NN          _   14  nsubj    _  SpaceAfter=No|Translit=shènglì
# 20488  14   迫使     _  VERB   VV  Voice=Cau    0   root    _    SpaceAfter=No|Translit=pòshǐ
#        id form lemma  upos xpos feats head  deprel deps                           misc
# 20491  17    次     _  NOUN  NNB     _   18  advmod    _      SpaceAfter=No|Translit=cì
# 20492  18   放棄     _  VERB   VV     _   14   ccomp    _  SpaceAfter=No|Translit=fàngqì
#       id form lemma  upos xpos feats head deprel deps                           misc
# 20499  4   堵塞     _  NOUN   NN     _    5  nsubj    _   SpaceAfter=No|Translit=dǔsāi
# 20500  5   導致     _  VERB   VV     _   17    dep    _  SpaceAfter=No|Translit=dǎozhì
#        id form lemma  upos xpos feats head  deprel deps                             misc
# 20511  16   方面     _  NOUN   NN     _   17  advmod    _  SpaceAfter=No|Translit=fāngmiàn
# 20512  17   也是     _  VERB   VC     _    0    root    _     SpaceAfter=No|Translit=yěshì
#        id form lemma  upos xpos feats head deprel deps                                     misc
# 20514  19   大陸     _  NOUN   NN     _   20  nsubj    _  Proper=True|SpaceAfter=No|Translit=dàlù
# 20515  20   出現     _  VERB   VV     _   18    obj    _           SpaceAfter=No|Translit=chūxiàn
#       id form lemma  upos xpos feats head deprel deps                           misc
# 20587  3   男人     _  NOUN   NN     _    4  nsubj    _  SpaceAfter=No|Translit=nánrén
# 20588  4   告訴     _  VERB   VV     _    0   root    _   SpaceAfter=No|Translit=gàosu
#        id form lemma  upos xpos feats head deprel deps                           misc
# 20617  33    人     _  NOUN   NN     _   30   conj    _     SpaceAfter=No|Translit=rén
# 20618  34   都是     _  VERB   VC     _    4  ccomp    _  SpaceAfter=No|Translit=dōushì
#        id form lemma  upos xpos feats head deprel deps                                        misc
# 20641  16   學校     _  NOUN   NN     _   13    obj    _  Proper=True|SpaceAfter=No|Translit=xuéxiào
# 20642  17   見面     _  VERB   VV     _    0   root    _             SpaceAfter=No|Translit=jiànmiàn
#       id form lemma  upos xpos feats head     deprel deps                          misc
# 20652  8    種     _  NOUN  NNB     _   18        clf    _  SpaceAfter=No|Translit=zhǒng
# 20653  9   延續     _  VERB   VV     _   18  acl:relcl    _  SpaceAfter=No|Translit=yánxù
#        id form lemma  upos xpos feats head deprel deps                           misc
# 20681  18   作品     _  NOUN   NN     _    0   root    _  SpaceAfter=No|Translit=zuòpǐn
# 20682  19    是     _  VERB   VC     _   18    dep    _     SpaceAfter=No|Translit=shì
#        id form lemma  upos xpos feats head     deprel deps                           misc
# 20702  11   合作     _  NOUN   NN     _   12      nsubj    _   SpaceAfter=No|Translit=hézuò
# 20703  12   導致     _  VERB   VV     _   15  acl:relcl    _  SpaceAfter=No|Translit=dǎozhì
#        id form lemma  upos xpos feats head deprel deps                            misc
# 20712  21   友誼     _  NOUN   NN     _   22  nsubj    _    SpaceAfter=No|Translit=youyì
# 20713  22   出現     _  VERB   VV     _    0   root    _  SpaceAfter=No|Translit=chūxiàn
#        id form lemma  upos xpos feats head deprel deps                          misc
# 20743  27   之後     _  NOUN   NN     _   28    obl    _   SpaceAfter=No|Translit=zhī後
# 20744  28   塑造     _  VERB   VV     _   15  ccomp    _  SpaceAfter=No|Translit=sùzào
#        id form lemma  upos xpos feats head     deprel deps                          misc
# 20769  18    場     _  NOUN  NNB     _   24        clf    _  SpaceAfter=No|Translit=chǎng
# 20770  19   持續     _  VERB   VV     _   24  acl:relcl    _  SpaceAfter=No|Translit=chíxù
#       id form lemma  upos xpos feats head deprel deps                                      misc
# 20778  2   後殿     _  NOUN   NN     _    3  nsubj    _  Proper=True|SpaceAfter=No|Translit=後diàn
# 20779  3    有     _  VERB   VV     _    1  ccomp    _                SpaceAfter=No|Translit=yǒu
#       id form lemma  upos xpos feats head     deprel deps                             misc
# 20781  5    個     _  NOUN  NNB     _    8        clf    _        SpaceAfter=No|Translit=gè
# 20782  6   平行     _  VERB   VV     _    8  acl:relcl    _  SpaceAfter=No|Translit=píngxíng
#       id form lemma  upos xpos feats head deprel deps                              misc
# 20794  1   傳統     _  NOUN   NN     _    2  nsubj    _  SpaceAfter=No|Translit=chuántǒng
# 20795  2    是     _  VERB   VC     _    0   root    _        SpaceAfter=No|Translit=shì
#       id form lemma  upos xpos feats head    deprel deps                          misc
# 20800  7   主題     _  NOUN   NN     _    4       obj    _  SpaceAfter=No|Translit=zhǔtí
# 20801  8    來     _  VERB   VV     _    4  mark:prt    _    SpaceAfter=No|Translit=lái
#       id form lemma  upos xpos feats head deprel deps                                        misc
# 20816  3   山脈     _  NOUN   NN     _    4  nsubj    _  Proper=True|SpaceAfter=No|Translit=shānmài
# 20817  4   形成     _  VERB   VV     _   12  xcomp    _            SpaceAfter=No|Translit=xíngchéng
#       id form lemma  upos xpos feats head deprel deps                             misc
# 20834  3   中心     _  NOUN   NN     _    4  nsubj    _  SpaceAfter=No|Translit=zhōngxīn
# 20835  4    屬     _  VERB   VV     _   19    dep    _       SpaceAfter=No|Translit=shǔ
#        id form lemma  upos xpos feats head deprel deps                         misc
# 20849  18   地區     _  NOUN   NN     _   19  nsubj    _  SpaceAfter=No|Translit=deqū
# 20850  19    是     _  VERB   VC     _    0   root    _   SpaceAfter=No|Translit=shì
#        id form lemma  upos xpos feats head deprel deps                            misc
# 20853  22   地殼     _  NOUN   NN     _   23  nsubj    _     SpaceAfter=No|Translit=deké
# 20854  23   潛沒     _  VERB   VV     _   24  xcomp    _  SpaceAfter=No|Translit=qiánméi
#        id form lemma  upos xpos feats head deprel deps                           misc
# 20870  13   不前     _  NOUN   NN     _    8   conj    _  SpaceAfter=No|Translit=bùqián
# 20871  14   導致     _  VERB   VV     _    0   root    _  SpaceAfter=No|Translit=dǎozhì
#        id form lemma  upos xpos feats head     deprel deps                           misc
# 20874  17    年     _  NOUN  NNB     _   18   obl:tmod    _    SpaceAfter=No|Translit=nián
# 20875  18   推翻     _  VERB   VV     _   22  acl:relcl    _  SpaceAfter=No|Translit=tuīfān
#       id form lemma  upos xpos feats head deprel deps                           misc
# 20887  7   女性     _  NOUN   NN     _    8  nsubj    _  SpaceAfter=No|Translit=nǚxìng
# 20888  8   獲得     _  VERB   VV     _   30    dep    _   SpaceAfter=No|Translit=huòde
#        id form lemma  upos xpos feats head deprel deps                            misc
# 20893  13   黨派     _  NOUN   NN     _   14  nsubj    _  SpaceAfter=No|Translit=dǎngpài
# 20894  14   得到     _  VERB   VV     _   30    dep    _    SpaceAfter=No|Translit=dedào
#        id form lemma  upos xpos feats head deprel deps                        misc
# 20901  21    人     _  NOUN   NN     _   22  nsubj    _  SpaceAfter=No|Translit=rén
# 20902  22    得     _  VERB   VV     _   30    dep    _   SpaceAfter=No|Translit=de
#        id form lemma  upos xpos feats head      deprel deps                             misc
# 20906  26   政治     _  NOUN   NN     _   27      advmod    _  SpaceAfter=No|Translit=zhèngzhì
# 20907  27  迫害犯     _  VERB   VV     _   30  nsubj:pass    _  SpaceAfter=No|Translit=pòhàifàn
#       id form lemma  upos xpos      feats head deprel deps                           misc
# 20919  7   乾預     _  NOUN   NN          _    5   conj    _     SpaceAfter=No|Translit=乾yù
# 20920  8   導致     _  VERB   VV  Voice=Cau   12  csubj    _  SpaceAfter=No|Translit=dǎozhì
#        id form lemma  upos xpos feats head deprel deps                           misc
# 20921   9   資本     _  NOUN   NN     _   10  nsubj    _   SpaceAfter=No|Translit=zīběn
# 20922  10   外流     _  VERB   VV     _    8  ccomp    _  SpaceAfter=No|Translit=wàiliú
#        id form lemma  upos xpos feats head deprel deps                           misc
# 20927  15   企業     _  NOUN   NN     _   16  nsubj    _    SpaceAfter=No|Translit=qǐyè
# 20928  16   破產     _  VERB   VV     _   12  ccomp    _  SpaceAfter=No|Translit=pòchǎn
#       id form lemma  upos xpos feats head     deprel deps                            misc
# 20934  5   邊界     _  NOUN   NN     _    6        obl    _  SpaceAfter=No|Translit=biānjiè
# 20935  6    到     _  VERB   VV     _   10  acl:relcl    _      SpaceAfter=No|Translit=dào
#        id form lemma  upos xpos feats head deprel deps                            misc
# 20946  17    線     _  NOUN   NN     _   18  nsubj    _     SpaceAfter=No|Translit=xiàn
# 20947  18   鏈接     _  VERB   VV     _    0   root    _  SpaceAfter=No|Translit=liànjiē
#        id form lemma  upos xpos feats head     deprel deps                             misc
# 20970  11   將軍     _  NOUN   NN     _   12      nsubj    _  SpaceAfter=No|Translit=jiāngjūn
# 20971  12   指揮     _  VERB   VV     _   15  acl:relcl    _    SpaceAfter=No|Translit=zhǐhuī
#        id form lemma  upos xpos feats head deprel deps                           misc
# 20974  15   軍隊     _  NOUN   NN     _   21  nsubj    _  SpaceAfter=No|Translit=jūnduì
# 20975  16    在     _  VERB   VV     _   21  advcl    _     SpaceAfter=No|Translit=zài
#        id form lemma  upos xpos feats head deprel deps                             misc
# 21002  12   鼓勵     _  NOUN   NN     _    8   conj    _      SpaceAfter=No|Translit=gǔlì
# 21003  13   正是     _  VERB   VC     _    0   root    _  SpaceAfter=No|Translit=zhèngshì
#       id form lemma  upos xpos feats head deprel deps                             misc
# 21042  4   將軍     _  NOUN   NN     _    5  nsubj    _  SpaceAfter=No|Translit=jiāngjūn
# 21043  5   領導     _  VERB   VV     _   12    dep    _   SpaceAfter=No|Translit=lǐngdǎo
#       id form lemma  upos xpos feats head deprel deps                           misc
# 21100  7   歷史     _  NOUN   NN     _    8  nsubj    _   SpaceAfter=No|Translit=lìshǐ
# 21101  8   包括     _  VERB   VV     _    0   root    _  SpaceAfter=No|Translit=bāokuò
#       id form lemma  upos xpos feats head deprel deps                             misc
# 21161  8   春天     _  NOUN   NN     _    9    obl    _  SpaceAfter=No|Translit=chūntiān
# 21162  9   告終     _  VERB   VV     _   12    dep    _  SpaceAfter=No|Translit=gàozhōng
#        id form lemma  upos xpos feats head deprel deps                           misc
# 21223  29   公司     _  NOUN   NN     _   30  nsubj    _  SpaceAfter=No|Translit=gōngsī
# 21224  30   發行     _  VERB   VV     _   26  ccomp    _  SpaceAfter=No|Translit=fāxíng
#       id form lemma  upos xpos feats head     deprel deps                        misc
# 21246  5    支     _  NOUN  NNB     _    9        clf    _  SpaceAfter=No|Translit=zhī
# 21247  6    在     _  VERB   VV     _    9  acl:relcl    _  SpaceAfter=No|Translit=zài
#        id form lemma  upos xpos feats head       deprel deps                             misc
# 21297  15   行動     _  NOUN   NN     _   16  obl:patient    _  SpaceAfter=No|Translit=xíngdòng
# 21298  16   告訴     _  VERB   VV     _    0         root    _     SpaceAfter=No|Translit=gàosu
#        id form lemma  upos xpos feats head deprel deps                             misc
# 21377  53   敵人     _  NOUN   NN     _   54    obl    _     SpaceAfter=No|Translit=dírén
# 21378  54   投降     _  VERB   VV     _   37  ccomp    _  SpaceAfter=No|Translit=tóujiàng
#        id form lemma  upos xpos feats head     deprel deps                         misc
# 21395  16    封     _  NOUN  NNB     _   21        clf    _  SpaceAfter=No|Translit=fēng
# 21396  17    來     _  VERB   VV     _   21  acl:relcl    _   SpaceAfter=No|Translit=lái
#        id form lemma  upos xpos feats head  deprel deps                            misc
# 21402  23   其中     _  NOUN   NN     _   24  advmod    _  SpaceAfter=No|Translit=qízhōng
# 21403  24   表示     _  VERB   VV     _   13   ccomp    _  SpaceAfter=No|Translit=biǎoshì
#        id form lemma  upos xpos feats head deprel deps                           misc
# 21405  26   總督     _  NOUN   NN     _   27  nsubj    _  SpaceAfter=No|Translit=zǒngdū
# 21406  27   宣布     _  VERB   VV     _   24  ccomp    _  SpaceAfter=No|Translit=xuānbù

# %%
def print_freq(df, column, top_freq=20):
    '''Prints a column's value counts and percentages in descending order'''
    freq_dict = df[column].value_counts()[:top_freq].to_dict()
    total = sum([val for val in freq_dict.values()])
    for pos in freq_dict:
        freq_dict[pos] = ( freq_dict[pos], 100*freq_dict[pos]/total )
        print(f'{pos}\t{freq_dict[pos][0]}\t{round(freq_dict[pos][1],2)}%')

# %%
print('ENG UPOS:')
print_freq(df_english, 'upos')
print('\nCHI UPOS:')
print_freq(df_chinese, 'upos')
# Out:
# ENG UPOS:
# NOUN	4040	19.07%
# ADP	2493	11.77%
# PUNCT	2451	11.57%
# VERB	2156	10.18%
# DET	2086	9.85%
# PROPN	1727	8.15%
# ADJ	1540	7.27%
# PRON	1021	4.82%
# AUX	1014	4.79%
# ADV	849	4.01%
# CCONJ	576	2.72%
# NUM	455	2.15%
# PART	426	2.01%
# SCONJ	290	1.37%
# SYM	42	0.2%
# X	16	0.08%
# INTJ	1	0.0%
#
# CHI UPOS:
# NOUN	5410	25.26%
# VERB	3467	16.19%
# PUNCT	2902	13.55%
# PART	1881	8.78%
# PROPN	1361	6.36%
# ADP	1288	6.01%
# ADV	1283	5.99%
# NUM	873	4.08%
# PRON	710	3.32%
# ADJ	650	3.04%
# AUX	618	2.89%
# DET	355	1.66%
# X	306	1.43%
# CCONJ	283	1.32%
# SCONJ	28	0.13%

# %%
ch = df_chinese.upos.value_counts().to_dict()
en = df_english.upos.value_counts().to_dict()
en
# Out:
# {'NOUN': 4040,
#  'ADP': 2493,
#  'PUNCT': 2451,
#  'VERB': 2156,
#  'DET': 2086,
#  'PROPN': 1727,
#  'ADJ': 1540,
#  'PRON': 1021,
#  'AUX': 1014,
#  'ADV': 849,
#  'CCONJ': 576,
#  'NUM': 455,
#  'PART': 426,
#  'SCONJ': 290,
#  'SYM': 42,
#  'X': 16,
#  'INTJ': 1}

# %%
print('ENG XPOS:')
print_freq(df_english, 'xpos')
print('\nCHI XPOS:')
print_freq(df_chinese, 'xpos')
# Out:
# ENG XPOS:
# NN	3119	15.72%
# IN	2716	13.69%
# DT	2121	10.69%
# NNP	1483	7.48%
# JJ	1445	7.29%
# NNS	1125	5.67%
# ,	1002	5.05%
# .	1000	5.04%
# VBD	875	4.41%
# RB	773	3.9%
# VBN	591	2.98%
# CC	576	2.9%
# VB	507	2.56%
# PRP	490	2.47%
# CD	460	2.32%
# VBZ	439	2.21%
# VBG	332	1.67%
# TO	267	1.35%
# VBP	259	1.31%
# PRP$	255	1.29%
#
# CHI XPOS:
# NN	4667	22.75%
# VV	3350	16.33%
# NNP	1361	6.63%
# DEC	1335	6.51%
# RB	1283	6.25%
# IN	1191	5.81%
# ,	1134	5.53%
# .	1001	4.88%
# CD	919	4.48%
# NNB	799	3.89%
# JJ	606	2.95%
# PRP	543	2.65%
# AS	398	1.94%
# VC	364	1.77%
# DT	355	1.73%
# FW	298	1.45%
# MD	286	1.39%
# CC	285	1.39%
# )	171	0.83%
# (	170	0.83%
